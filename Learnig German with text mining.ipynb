# %%
import re
import collections

# %% [markdown]
# The book I am using is in pdf format. So to convert it into a text format, I modified and used the Stanford code of converting a pdf to a text to run on python 3.7

# %%
from io import StringIO
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
import os
import sys, getopt

#converts pdf, returns its text content as a string
def convert(fname, pages=None):
    if not pages:
        pagenums = set()
    else:
        pagenums = set(pages)

    output = StringIO()
    manager = PDFResourceManager()
    converter = TextConverter(manager, output, laparams=LAParams())
    interpreter = PDFPageInterpreter(manager, converter)

    infile = open(fname, 'rb')
    for page in PDFPage.get_pages(infile, pagenums):
        interpreter.process_page(page)
    infile.close()
    converter.close()
    text = output.getvalue()
    output.close
    return text 
   
text = convert('Carroll__Wunderland.pdf')

# %%
text
# Out:
# ' \n \n\nAlice’s Abenteuer im Wunderland\n\nvon\n\nLewis Carroll\n\nAus dem Englischen von\nAntonie Zimmermann\n\nAutorisierte Ausgabe\n\nMit den Illustrationen von\n\nJohn Tenniel\n\nKoloriert von\n\nGünter Jürgensmeier\n\nFür Luzie\n\nJohann Friedrich Hartknoch\n\nLeipzig\n\n[1869]\n\n\x0c\x0c \n \n \n \n \n \n\nInhalt\n\n01. Hinunter in den Kaninchenbau.   . . . . . . . . . . . . . . . .\n02. Der Thränenpfuhl.   . . . . . . . . . . . . . . . . . . . . . . . . . .\n03. Caucus-Rennen und was daraus wird.    . . . . . . . . . . .\n04. Die Wohnung des Kaninchens.   . . . . . . . . . . . . . . . . .\n05. Guter Rath von einer Raupe.   . . . . . . . . . . . . . . . . . . .\n06. Ferkel und Pfeffer.   . . . . . . . . . . . . . . . . . . . . . . . . . . .\n07. Die tolle Theegesellschaft.   . . . . . . . . . . . . . . . . . . . . .\n08. Das Croquetfeld der Königin.   . . . . . . . . . . . . . . . . . .\n09. Die Geschichte der falschen Schildkröte.    . . . . . . . . .\n10. Das Hummerballet.   . . . . . . . . . . . . . . . . . . . . . . . . . .\n11. Wer hat die Kuchen gestohlen?   . . . . . . . . . . . . . . . . .\n12. Alice ist die Klügste.   . . . . . . . . . . . . . . . . . . . . . . . . .\n\n  7\n \n  15\n \n  23\n \n  31\n \n  41\n \n  51\n \n  62\n \n  72\n \n  82\n \n \n  92\n   100\n   108\n\n\x0cDer  Verfasser  wünscht  hiermit  seine  Anerkennung  gegen  die \nÜbersetzerin  auszusprechen,  die  einige  eingestreute  Parodien \nenglischer  Kinderlieder,  welche  der  deutschen  Jugend  unver-\nständlich  gewesen  wären,  durch  dergleichen  von  bekannten \ndeutschen Gedichten ersetzt hat. Ebenso sind für die oft unüber-\nsetzbaren  englischen Wortspiele  passende  deutsche  eingescho-\nben worden, welche das Buch allein der Gewandtheit der Über-\nsetzerin verdankt.\n\n\x0c                        O schöner, goldner Nachmittag,\n                        Wo Flut und Himmel lacht!\n                        Von schwacher Kindeshand bewegt,\n                        Die Ruder plätschern sacht –\n                        Das Steuer hält ein Kindesarm\n                        Und lenket unsre Fahrt.\n\n                        So fuhren wir gemächlich hin\n                        Auf träumerischen Wellen –\n                        Doch ach! die drei vereinten sich,\n                        Den müden Freund zu quälen –\n                        Sie trieben ihn, sie drängten ihn,\n                        Ein Mährchen zu erzählen.\n\n                        Die Erste gab’s Commandowort;\n                        O schnell, o fange an!\n                        Und mach’ es so, die Zweite bat,\n                        Daß man recht lachen kann!\n                        Die Dritte ließ ihm keine Ruh\n                        Mit wie? und wo? und wann?\n\n                        Jetzt lauschen sie vom Zauberland\n                        Der wunderbaren Mähr’;\n                        Mit Thier und Vogel sind sie bald\n                        In freundlichem Verkehr,\n                        Und fühlen sich so heimisch dort,\n                        Als ob es Wahrheit wär’. –\n\n                        Und jedes Mal, wenn Fantasie\n                        Dem Freunde ganz versiegt: –\n                        »Das Übrige ein ander Mal!«\n                        O nein, sie leiden’s nicht.\n                        »Es ist ja schon ein ander Mal!« –\n                        So rufen sie vergnügt.\n\n\x0c                        So ward vom schönen Wunderland\n                        Das Märchen ausgedacht,\n                        So langsam Stück für Stück erzählt,\n                        Beplaudert und belacht,\n                        Und froh, als es zu Ende war,\n                        Der Weg nach Haus gemacht.\n\n                        Alice! o nimm es freundlich an!\n                        Leg’ es mit güt’ger Hand\n                        Zum Strauße, den Erinnerung\n                        Aus Kindheitsträumen band,\n                        ...

# %% [markdown]
# #### Normalise text
# Normlaise text by removing punctuation and converting all leters into lower case

# %%
def normalise(text):
    # convert to lower case
    text = text.lower()
    
    # remove punctuations
    text = re.sub(r'\W', ' ', text)
    return text

# %% [markdown]
# #### Words sequence model
# Collect words in the sequence of the given n

# %%
def Words_seq(text, n):
    # normalise text
    text = normalise(text)
    # tokenize 
    text = text.split()
    
    seq = list(zip(*[text[i:] for i in range(n)]))
    return seq

# %%
seq = Words_seq(text, 3)
seq
# Out:
# [('alice', 's', 'abenteuer'),
#  ('s', 'abenteuer', 'im'),
#  ('abenteuer', 'im', 'wunderland'),
#  ('im', 'wunderland', 'von'),
#  ('wunderland', 'von', 'lewis'),
#  ('von', 'lewis', 'carroll'),
#  ('lewis', 'carroll', 'aus'),
#  ('carroll', 'aus', 'dem'),
#  ('aus', 'dem', 'englischen'),
#  ('dem', 'englischen', 'von'),
#  ('englischen', 'von', 'antonie'),
#  ('von', 'antonie', 'zimmermann'),
#  ('antonie', 'zimmermann', 'autorisierte'),
#  ('zimmermann', 'autorisierte', 'ausgabe'),
#  ('autorisierte', 'ausgabe', 'mit'),
#  ('ausgabe', 'mit', 'den'),
#  ('mit', 'den', 'illustrationen'),
#  ('den', 'illustrationen', 'von'),
#  ('illustrationen', 'von', 'john'),
#  ('von', 'john', 'tenniel'),
#  ('john', 'tenniel', 'koloriert'),
#  ('tenniel', 'koloriert', 'von'),
#  ('koloriert', 'von', 'günter'),
#  ('von', 'günter', 'jürgensmeier'),
#  ('günter', 'jürgensmeier', 'für'),
#  ('jürgensmeier', 'für', 'luzie'),
#  ('für', 'luzie', 'johann'),
#  ('luzie', 'johann', 'friedrich'),
#  ('johann', 'friedrich', 'hartknoch'),
#  ('friedrich', 'hartknoch', 'leipzig'),
#  ('hartknoch', 'leipzig', '1869'),
#  ('leipzig', '1869', 'inhalt'),
#  ('1869', 'inhalt', '01'),
#  ('inhalt', '01', 'hinunter'),
#  ('01', 'hinunter', 'in'),
#  ('hinunter', 'in', 'den'),
#  ('in', 'den', 'kaninchenbau'),
#  ('den', 'kaninchenbau', '02'),
#  ('kaninchenbau', '02', 'der'),
#  ('02', 'der', 'thränenpfuhl'),
#  ('der', 'thränenpfuhl', '03'),
#  ('thränenpfuhl', '03', 'caucus'),
#  ('03', 'caucus', 'rennen'),
#  ('caucus', 'rennen', 'und'),
#  ('rennen', 'und', 'was'),
#  ('und', 'was', 'daraus'),
#  ('was', 'daraus', 'wird'),
#  ('daraus', 'wird', '04'),
#  ('wird', '04', 'die'),
#  ('04', 'die', 'wohnung'),
#  ('die', 'wohnung', 'des'),
#  ('wohnung', 'des', 'kaninchens'),
#  ('des', 'kaninchens', '05'),
#  ('kaninchens', '05', 'guter'),
#  ('05', 'guter', 'rath'),
#  ('guter', 'rath', 'von'),
#  ('rath', 'von', 'einer'),
#  ('von', 'einer', 'raupe'),
#  ('einer', 'raupe', '06'),
#  ('raupe', '06', 'ferkel'),
#  ('06', 'ferkel', 'und'),
#  ('ferkel', 'und', 'pfeffer'),
#  ('und', 'pfeffer', '07'),
#  ('pfeffer', '07', 'die'),
#  ('07', 'die', 'tolle'),
#  ('die', 'tolle', 'theegesellschaft'),
#  ('tolle', 'theegesellschaft', '08'),
#  ('theegesellschaft', '08', 'das'),
#  ('08', 'das', 'croquetfeld'),
#  ('das', 'croquetfeld', 'der'),
#  ('croquetfeld', 'der', 'königin'),
#  ('der', 'königin', '09'),
#  ('königin', '09', 'die'),
#  ('09', 'die', 'geschichte'),
#  ('die', 'geschichte', 'der'),
#  ('geschichte', 'der', 'falschen'),
#  ('der', 'falschen', 'schildkröte'),
#  ('falschen', 'schildkröte', '10'),
#  ('schildkröte', '10', 'das'),
#  ('10', 'das', 'hummerballet'),
#  ('das', 'hummerballet', '11'),
#  ('hummerballet', '11', 'wer'),
#  ('11', 'wer', 'hat'),
#  ('wer', 'hat', 'die'),
#  ('hat', 'die', 'kuchen'),
#  ('die', 'kuchen', 'gestohlen'),
#  ('kuchen', 'gestohlen', '12'),
#  ('gestohlen', '12', 'alice'),
#  ('12', 'alice', 'ist'),
#  ('alice', 'ist', 'die'),
#  ('ist', 'die', 'klügste'),
#  ('die', 'klügste', '7'),
#  ('klügste', '7', '15'),
#  ('7', '15', '23'),
#  ('15', '23', '31'),
#  ('23', '31', '41'),
#  ('31', '41', '51'),
#  ('41', '51', '62'),
#  ('51', '62', '72'),
#  ('62', '72', '82'),
#  ('72', '82', '92'),
#  ('82', '92', '100'),
#  ('92', '100', '108'),
#  ('100', '108', 'der'),
#  ('108', 'der', 'verfasser'),
#  ('der', 'verfasser', 'wünscht'),
#  ('verfasser', 'wünscht', 'hiermit'),
#  ('wünscht', 'hiermit', 'seine'),
#  ('hiermit', 'seine', 'anerkennung'),
#  ('seine', 'anerkennung', 'gegen'),
#  ('anerkennung', 'gegen', 'die'),
#  ('gegen', 'die', 'übersetzerin'),
#  ('die', 'übersetzerin', 'auszusprechen'),
#  ('übersetzerin', 'auszusprechen', 'die'),
#  ('auszusprechen', 'die', 'einige'),
#  ('die', 'einige', 'eingestreute'),
#  ('einige', 'eingestreute', 'parodien'),
#  ('eingestreute', 'parodien', 'englischer'),
#  ('parodien', 'englischer', 'kinderlieder'),
#  ('englischer', 'kinderlieder', 'welche'),
#  ('kinderlieder', 'welche', 'der'),
#  ('welche', 'der', 'deutschen'),
#  ('der', 'deutschen', 'jugend'),
#  ('deutschen', 'jugend', 'unver'),
#  ('jugend', 'unver', 'ständlich'),
#  ('unver', 'ständlich', 'gewesen'),
#  ('ständlich', 'gewesen', 'wären'),
#  ('gewesen', 'wären', 'durch'),
#  ('wären', 'durch', 'dergleichen'),
#  ('durch', 'dergleichen', 'von'),
#  ('dergleichen', 'von', 'bekannten'),
#  ('von', 'bekannten', 'deutschen'),
#  ('bekannten', 'deutschen', 'gedichten'),
#  ('deutschen', 'gedichten', 'ersetzt'),
#  ('gedichten', 'ersetzt', 'hat'),
#  ('ersetzt', 'hat', 'ebenso'),
#  ('hat', 'ebenso', 'sind'),
#  ('ebenso', 'sind', 'für'),
#  ('sind', 'für', 'die'),
#  ('für', 'die', 'oft'),
#  ('die', 'oft', 'unüber'),
#  ('oft', 'unüber', 'setzbaren'),
#  ('unüber', 'setzbaren', 'englischen'),
#  ('setzbaren', 'englischen', 'wortspiele'),
#  ('englischen', 'wortspiele', 'passende'),
#  ('wortspiele', 'passende', 'deutsche'),
#  ('passende', 'deutsche', 'eingescho'),
#  ('deutsche', 'eingescho', 'ben'),
#  ('eingescho', 'ben', 'worden'),
#  ('ben', 'worden', 'welche'),
#  ('worden', 'welche', 'das'),
#  ('welche', 'das', 'buch'),
#  ('das', 'buch', 'allein'),
#  ('buch', 'allein', 'der'),
#  ('allein', 'der', 'gewandtheit'),
#  ('der', 'gewandtheit', 'der'),
#  ('gewandtheit', 'der', 'über'),
#  ('der', 'über', 'setzerin'),
#  ('über', 'setzerin', 'verdankt'),
#  ('setzerin', 'verdankt', 'o'),
#  ('verdankt', 'o', 'schöner'),
#  ('o', 'schöner', 'goldner'),
#  ('schöner', 'goldner', 'nachmittag'),
#  ('goldner', 'nachmittag', 'wo'),
#  ('nachmittag', 'wo', 'flut'),
#  ('wo', 'flut', 'und'),
#  ('flut', 'und', 'himmel'),
#  ('und', 'himmel', 'lacht'),
#  ('himmel', 'lacht', 'von'),
#  ('lacht', 'von', 'schwacher'),
#  ('von', 'schwacher', 'kindeshand'),
#  ('schwacher', 'kindeshand', 'bewegt'),
#  ('kindeshand', 'bewegt', 'die'),
#  ('bewegt', 'die', 'ruder'),
#  ('die', 'ruder', 'plätschern'),
#  ('ruder', 'plätschern', 'sacht'),
#  ('plätschern', 'sacht', 'das'),
#  ('sacht', 'das', 'steuer'),
#  ('das', 'steuer', 'hält'),
#  ('steuer', 'hält', 'ein'),
#  ('hält', 'ein', 'kindesarm'),
#  ('ein', 'kindesarm', 'und'),
#  ('kindesarm', 'und', 'lenket'),
#  ('und', 'lenket', 'unsre'),
#  ('lenket', 'unsre', 'fahrt'),
#  ('unsre', 'fahrt', 'so'),
#  ('fahrt', 'so', 'fuhren'),
#  ('so', 'fuhren', 'wir'),
#  ('fuhren', 'wir', 'gemächlich'),
#  ('wir', 'gemächlich', 'hin'),
#  ('gemächlich', 'hin', 'auf'),
#  ('hin', 'auf', 'träumerischen'),
#  ('auf', 'träumerischen', 'wellen'),
#  ('träumerischen', 'wellen', 'doch'),
#  ('wellen', 'doch', 'ach'),
#  ('doch', 'ach', 'die'),
#  ('ach', 'die', 'drei'),
#  ('die', 'drei', 'vereinten'),
#  ('drei', 'vereinten', 'sich'),
#  ('vereinten', 'sich', 'den'),
#  ('sich', 'den', 'müden'),
#  ('den', 'müden', 'freund'),
#  ('müden', 'freund', 'zu'),
#  ('freund', 'zu', 'quälen'),
#  ('zu', 'quälen', 'sie'),
#  ('quälen', 'sie', 'trieben'),
#  ('sie', 'trieben', 'ihn'),
#  ('trieben', 'ihn', 'sie'),
#  ('ihn', 'sie', 'drängten'),
#  ('sie', 'drängten', 'ihn'),
#  ('drängten', 'ihn', 'ein'),
#  ('ihn', 'ein', 'mährchen'),
#  ('ein', 'mährchen', 'zu'),
#  ('mährchen', 'zu', 'erzählen'),
#  ('zu', 'erzählen', 'die'),
#  ('erzählen', 'die', 'erste'),
#  ('die', 'erste', 'gab'),
#  ('erste', 'gab', 's'),
#  ('gab', 's', 'commandowort'),
#  ('s', 'commandowort', 'o'),
#  ('commandowort', 'o', 'schnell'),
#  ('o', 'schnell', 'o'),
#  ('schnell', 'o', 'fange'),
#  ('o', 'fange', 'an'),
#  ('fange', 'an', 'und'),
#  ('an', 'und', 'mach'),
#  ('und', 'mach', 'es'),
#  ('mach', 'es', 'so'),
#  ('es', 'so', 'die'),
#  ('so', 'die', 'zweite'),
#  ('die', 'zweite', 'bat'),
#  ('zweite', 'bat', 'daß'),
#  ('bat', 'daß', 'man'),
#  ('daß', 'man', 'recht'),
#  ('man', 'recht', 'lachen'),
#  ('recht', 'lachen', 'kann'),
#  ('lachen', 'kann', 'die'),
#  ('kann', 'die', 'dritte'),
#  ('die', 'dritte', 'ließ'),
#  ('dritte', 'ließ', 'ihm'),
#  ('ließ', 'ihm', 'keine'),
#  ('ihm', 'keine', 'ruh'),
#  ('keine', 'ruh', 'mit'),
#  ('ruh', 'mit', 'wie'),
#  ('mit', 'wie', 'und'),
#  ('wie', 'und', 'wo'),
#  ('und', 'wo', 'und'),
#  ('wo', 'und', 'wann'),
#  ('und', 'wann', 'jetzt'),
#  ('wann', 'jetzt', 'lauschen'),
#  ('jetzt', 'lauschen', 'sie'),
#  ('lauschen', 'sie', 'vom'),
#  ('sie', 'vom', 'zauberland'),
#  ('vom', 'zauberland', 'der'),
#  ('zauberland', 'der', 'wunderbaren'),
#  ('der', 'wunderbaren', 'mähr'),
#  ('wunderbaren', 'mähr', 'mit'),
#  ('mähr', 'mit', 'thier'),
#  ('mit', 'thier', 'und'),
#  ('thier', 'und', 'vogel'),
#  ('und', 'vogel', 'sind'),
#  ('vogel', 'sind', 'sie'),
#  ('sind', 'sie', 'bald'),
#  ('sie', 'bald', 'in'),
#  ('bald', 'in', 'freundlichem'),
#  ('in', 'freundlichem', 'verkehr'),
#  ('freundlichem', 'verkehr', 'und'),
#  ('verkehr', 'und', 'fühlen'),
#  ('und', 'fühlen', 'sich'),
#  ('fühlen', 'sich', 'so'),
#  ('sich', 'so', 'heimisch'),
#  ('so', 'heimisch', 'dort'),
#  ('heimisch', 'dort', 'als'),
#  ('dort', 'als', 'ob'),
#  ('als', 'ob', 'es'),
#  ('ob', 'es', 'wahrheit'),
#  ('es', 'wahrheit', 'wär'),
#  ('wahrheit', 'wär', 'und'),
#  ('wär', 'und', 'jedes'),
#  ('und', 'jedes', 'mal'),
#  ('jedes', 'mal', 'wenn'),
#  ('mal', 'wenn', 'fantasie'),
#  ('wenn', 'fantasie', 'dem'),
#  ('fantasie', 'dem', 'freunde'),
#  ('dem', 'freunde', 'ganz'),
#  ('freunde', 'ganz', 'versiegt'),
#  ('ganz', 'versiegt', 'das'),
#  ('versiegt', 'das', 'übrige'),
#  ('das', 'übrige', 'ein'),
#  ('übrige', 'ein', 'ander'),
#  ('ein', 'ander', 'mal'),
#  ('ander', 'mal', 'o'),
#  ('mal', 'o', 'nein'),
#  ('o', 'nein', 'sie'),
#  ('nein', 'sie', 'leiden'),
#  ('sie', 'leiden', 's'),
#  ('leiden', 's', 'nicht'),
#  ('s', 'nicht', 'es'),
#  ('nicht', 'es', 'ist'),
#  ('es', 'ist', 'ja'),
#  ('ist', 'ja', 'schon'),
#  ('ja', 'schon', 'ein'),
#  ('schon', 'ein', 'ander'),
#  ('ein', 'ander', 'mal'),
#  ('ander', 'mal', 'so'),
#  ('mal', 'so', 'rufen'),
#  ('so', 'rufen', 'sie'),
#  ('rufen', 'sie', 'vergnügt'),
#  ('sie', 'vergnügt', 'so'),
#  ('vergnügt', 'so', 'ward'),
#  ('so', 'ward', 'vom'),
#  ('ward', 'vom', 'schönen'),
#  ('vom', 'schönen', 'wunderland'),
#  ('schönen', 'wunderland', 'das'),
#  ('wunderland', 'das', 'märchen'),
#  ('das', 'märchen', 'ausgedacht'),
#  ('märchen', 'ausgedacht', 'so'),
#  ('ausgedacht', 'so', 'langsam'),
#  ('so', 'langsam', 'stück'),
#  ('langsam', 'stück', 'für'),
#  ('stück', 'für', 'stück'),
#  ('für', 'stück', 'erzählt'),
#  ('stück', 'erzählt', 'beplaudert'),
#  ('erzählt', 'beplaudert', 'und'),
#  ('beplaudert', 'und', 'belacht'),
#  ('und', 'belacht', 'und'),
#  ('belacht', 'und', 'froh'),
#  ('und', 'froh', 'als'),
#  ('froh', 'als', 'es'),
#  ('als', 'es', 'zu'),
#  ('es', 'zu', 'ende'),
#  ('zu', 'ende', 'war'),
#  ('ende', 'war', 'der'),
#  ('war', 'der', 'weg'),
#  ('der', 'weg', 'nach'),
#  ('weg', 'nach', 'haus'),
#  ('nach', 'haus', 'gemacht'),
#  ('haus', 'gemacht', 'alice'),
#  ('gemacht', 'alice', 'o'),
#  ('alice', 'o', 'nimm'),
#  ('o', 'nimm', 'es'),
#  ('nimm', 'es', 'freundlich'),
#  ('es', 'freundlich', 'an'),
#  ('freundlich', 'an', 'leg'),
#  ('an', 'leg', 'es'),
#  ('leg', 'es', 'mit'),
#  ('es', 'mit', 'güt'),
#  ('mit', 'güt', 'ger'),
#  ('güt', 'ger', 'hand'),
#  ('ger', 'hand', 'zum'),
#  ('hand', 'zum', 'strauße'),
#  ('zum', 'strauße', 'den'),
#  ('strauße', 'den', 'erinnerung'),
#  ('den', 'erinnerung', 'aus'),
#  ('erinnerung', 'aus', 'kindheitsträumen'),
#  ('aus', 'kindheitsträumen', 'band'),
#  ('kindheitsträumen', 'band', 'gleich'),
#  ('band', 'gleich', 'welken'),
#  ('gleich', 'welken', 'blüthen'),
#  ('welken', 'blüthen', 'mitgebracht'),
#  ('blüthen', 'mitgebracht', 'aus'),
#  ('mitgebracht', 'aus', 'liebem'),
#  ('aus', 'liebem', 'fernen'),
#  ('liebem', 'fernen', 'land'),
#  ('fernen', 'land', 'erstes'),
#  ('land', 'erstes', 'kapitel'),
#  ('erstes', 'kapitel', 'hinunter'),
#  ('kapitel', 'hinunter', 'in'),
#  ('hinunter', 'in', 'den'),
#  ('in', 'den', 'kaninchenbau'),
#  ('den', 'kaninchenbau', 'alice'),
#  ('kaninchenbau', 'alice', 'fing'),
#  ('alice', 'fing', 'an'),
#  ('fing', 'an', 'sich'),
#  ('an', 'sich', 'zu'),
#  ('sich', 'zu', 'langweilen'),
#  ('zu', 'langweilen', 'sie'),
#  ('langweilen', 'sie', 'saß'),
#  ('sie', 'saß', 'schon'),
#  ('saß', 'schon', 'lange'),
#  ('schon', 'lange', 'bei'),
#  ('lange', 'bei', 'ihrer'),
#  ('bei', 'ihrer', 'schwester'),
#  ('ihrer', 'schwester', 'am'),
#  ('schwester', 'am', 'ufer'),
#  ('am', 'ufer', 'und'),
#  ('ufer', 'und', 'hatte'),
#  ('und', 'hatte', 'nichts'),
#  ('hatte', 'nichts', 'zu'),
#  ('nichts', 'zu', 'thun'),
#  ('zu', 'thun', 'das'),
#  ('thun', 'das', 'buch'),
#  ('das', 'buch', 'das'),
#  ('buch', 'das', 'ihre'),
#  ('das', 'ihre', 'schwester'),
#  ('ihre', 'schwester', 'las'),
#  ('schwester', 'las', 'gefiel'),
#  ('las', 'gefiel', 'ihr'),
#  ('gefiel', 'ihr', 'nicht'),
#  ('ihr', 'nicht', 'denn'),
#  ('nicht', 'denn', 'es'),
#  ('denn', 'es', 'waren'),
#  ('es', 'waren', 'weder'),
#  ('waren', 'weder', 'bilder'),
#  ('weder', 'bilder', 'noch'),
#  ('bilder', 'noch', 'gespräche'),
#  ('noch', 'gespräche', 'darin'),
#  ('gespräche', 'darin', 'und'),
#  ('darin', 'und', 'was'),
#  ('und', 'was', 'nützen'),
#  ('was', 'nützen', 'bücher'),
#  ('nützen', 'bücher', 'dachte'),
#  ('bücher', 'dachte', 'alice'),
#  ('dachte', 'alice', 'ohne'),
#  ('alice', 'ohne', 'bilder'),
#  ('ohne', 'bilder', 'und'),
#  ('bilder', 'und', 'gespräche'),
#  ('und', 'gespräche', 'sie'),
#  ('gespräche', 'sie', 'überlegte'),
#  ('sie', 'überlegte', 'sich'),
#  ('überlegte', 'sich', 'eben'),
#  ('sich', 'eben', 'so'),
#  ('eben', 'so', 'gut'),
#  ('so', 'gut', 'es'),
#  ('gut', 'es', 'ging'),
#  ('es', 'ging', 'denn'),
#  ('ging', 'denn', 'sie'),
#  ('denn', 'sie', 'war'),
#  ('sie', 'war', 'schläf'),
#  ('war', 'schläf', 'rig'),
#  ('schläf', 'rig', 'und'),
#  ('rig', 'und', 'dumm'),
#  ('und', 'dumm', 'von'),
#  ('dumm', 'von', 'der'),
#  ('von', 'der', 'hitze'),
#  ('der', 'hitze', 'ob'),
#  ('hitze', 'ob', 'es'),
#  ('ob', 'es', 'der'),
#  ('es', 'der', 'mühe'),
#  ('der', 'mühe', 'werth'),
#  ('mühe', 'werth', 'sei'),
#  ('werth', 'sei', 'aufzu'),
#  ('sei', 'aufzu', 'stehen'),
#  ('aufzu', 'stehen', 'und'),
#  ('stehen', 'und', 'gänseblümchen'),
#  ('und', 'gänseblümchen', 'zu'),
#  ('gänseblümchen', 'zu', 'pflücken'),
#  ('zu', 'pflücken', 'um'),
#  ('pflücken', 'um', 'eine'),
#  ('um', 'eine', 'kette'),
#  ('eine', 'kette', 'damit'),
#  ('kette', 'damit', 'zu'),
#  ('damit', 'zu', 'machen'),
#  ('zu', 'machen', 'als'),
#  ('machen', 'als', 'plötzlich'),
#  ('als', 'plötzlich', 'ein'),
#  ('plötzlich', 'ein', 'weißes'),
#  ('ein', 'weißes', 'kaninchen'),
#  ('weißes', 'kaninchen', 'mit'),
#  ('kaninchen', 'mit', 'rothen'),
#  ('mit', 'rothen', 'augen'),
#  ('rothen', 'augen', 'dicht'),
#  ('augen', 'dicht', 'an'),
#  ('dicht', 'an', 'ihr'),
#  ('an', 'ihr', 'vorbeirannte'),
#  ('ihr', 'vorbeirannte', '8'),
#  ('vorbeirannte', '8', 'dies'),
#  ('8', 'dies', 'war'),
#  ('dies', 'war', 'grade'),
#  ('war', 'grade', 'nicht'),
#  ('grade', 'nicht', 'sehr'),
#  ('nicht', 'sehr', 'merkwürdig'),
#  ('sehr', 'merkwürdig', 'alice'),
#  ('merkwürdig', 'alice', 'fand'),
#  ('alice', 'fand', 'es'),
#  ('fand', 'es', 'auch'),
#  ('es', 'auch', 'nicht'),
#  ('auch', 'nicht', 'sehr'),
#  ('nicht', 'sehr', 'außerordentlich'),
#  ('sehr', 'außerordentlich', 'daß'),
#  ('außerordentlich', 'daß', 'sie'),
#  ('daß', 'sie', 'das'),
#  ('sie', 'das', 'kaninchen'),
#  ('das', 'kaninchen', 'sagen'),
#  ('kaninchen', 'sagen', 'hörte'),
#  ('sagen', 'hörte', 'o'),
#  ('hörte', 'o', 'weh'),
#  ('o', 'weh', 'o'),
#  ('weh', 'o', 'weh'),
#  ('o', 'weh', 'ich'),
#  ('weh', 'ich', 'werde'),
#  ('ich', 'werde', 'zu'),
#  ('werde', 'zu', 'spät'),
#  ('zu', 'spät', 'kommen'),
#  ('spät', 'kommen', 'als'),
#  ('kommen', 'als', 'sie'),
#  ('als', 'sie', 'es'),
#  ('sie', 'es', 'später'),
#  ('es', 'später', 'wieder'),
#  ('später', 'wieder', 'überlegte'),
#  ('wieder', 'überlegte', 'fiel'),
#  ('überlegte', 'fiel', 'ihr'),
#  ('fiel', 'ihr', 'ein'),
#  ('ihr', 'ein', 'daß'),
#  ('ein', 'daß', 'sie'),
#  ('daß', 'sie', 'sich'),
#  ('sie', 'sich', 'darüber'),
#  ('sich', 'darüber', 'hätte'),
#  ('darüber', 'hätte', 'wundern'),
#  ('hätte', 'wundern', 'sollen'),
#  ('wundern', 'sollen', 'doch'),
#  ('sollen', 'doch', 'zur'),
#  ('doch', 'zur', 'zeit'),
#  ('zur', 'zeit', 'kam'),
#  ('zeit', 'kam', 'es'),
#  ('kam', 'es', 'ihr'),
#  ('es', 'ihr', 'alles'),
#  ('ihr', 'alles', 'ganz'),
#  ('alles', 'ganz', 'natürlich'),
#  ('ganz', 'natürlich', 'vor'),
#  ('natürlich', 'vor', 'aber'),
#  ('vor', 'aber', 'als'),
#  ('aber', 'als', 'das'),
#  ('als', 'das', 'kaninchen'),
#  ('das', 'kaninchen', 'seine'),
#  ('kaninchen', 'seine', 'uhr'),
#  ('seine', 'uhr', 'aus'),
#  ('uhr', 'aus', 'der'),
#  ('aus', 'der', 'westentasche'),
#  ('der', 'westentasche', 'zog'),
#  ('westentasche', 'zog', 'nach'),
#  ('zog', 'nach', 'der'),
#  ('nach', 'der', 'zeit'),
#  ('der', 'zeit', 'sah'),
#  ('zeit', 'sah', 'und'),
#  ('sah', 'und', 'eilig'),
#  ('und', 'eilig', 'fortlief'),
#  ('eilig', 'fortlief', 'sprang'),
#  ('fortlief', 'sprang', 'alice'),
#  ('sprang', 'alice', 'auf'),
#  ('alice', 'auf', 'denn'),
#  ('auf', 'denn', 'es'),
#  ('denn', 'es', 'war'),
#  ('es', 'war', 'ihr'),
#  ('war', 'ihr', 'doch'),
#  ('ihr', 'doch', 'noch'),
#  ('doch', 'noch', 'nie'),
#  ('noch', 'nie', 'vorgekommen'),
#  ('nie', 'vorgekommen', 'ein'),
#  ('vorgekommen', 'ein', 'kaninchen'),
#  ('ein', 'kaninchen', 'mit'),
#  ('kaninchen', 'mit', 'einer'),
#  ('mit', 'einer', 'westentasche'),
#  ('einer', 'westentasche', 'und'),
#  ('westentasche', 'und', 'einer'),
#  ('und', 'einer', 'uhr'),
#  ('einer', 'uhr', 'darin'),
#  ('uhr', 'darin', 'zu'),
#  ('darin', 'zu', 'sehen'),
#  ('zu', 'sehen', 'vor'),
#  ('sehen', 'vor', 'neugierde'),
#  ('vor', 'neugierde', 'brennend'),
#  ('neugierde', 'brennend', 'rannte'),
#  ('brennend', 'rannte', 'sie'),
#  ('rannte', 'sie', 'ihm'),
#  ('sie', 'ihm', 'nach'),
#  ('ihm', 'nach', 'über'),
#  ('nach', 'über', 'den'),
#  ('über', 'den', 'grasplatz'),
#  ('den', 'grasplatz', 'und'),
#  ('grasplatz', 'und', 'kam'),
#  ('und', 'kam', 'noch'),
#  ('kam', 'noch', 'zur'),
#  ('noch', 'zur', 'rechten'),
#  ('zur', 'rechten', 'zeit'),
#  ('rechten', 'zeit', 'um'),
#  ('zeit', 'um', 'es'),
#  ('um', 'es', 'in'),
#  ('es', 'in', 'ein'),
#  ('in', 'ein', 'großes'),
#  ('ein', 'großes', 'loch'),
#  ('großes', 'loch', 'unter'),
#  ('loch', 'unter', 'der'),
#  ('unter', 'der', 'hecke'),
#  ('der', 'hecke', 'schlüpfen'),
#  ('hecke', 'schlüpfen', 'zu'),
#  ('schlüpfen', 'zu', 'sehen'),
#  ('zu', 'sehen', 'den'),
#  ('sehen', 'den', 'nächsten'),
#  ('den', 'nächsten', 'augenblick'),
#  ('nächsten', 'augenblick', 'war'),
#  ('augenblick', 'war', 'sie'),
#  ('war', 'sie', 'ihm'),
#  ('sie', 'ihm', 'nach'),
#  ('ihm', 'nach', 'in'),
#  ('nach', 'in', 'das'),
#  ('in', 'das', 'loch'),
#  ('das', 'loch', 'hi'),
#  ('loch', 'hi', 'neingesprungen'),
#  ('hi', 'neingesprungen', 'ohne'),
#  ('neingesprungen', 'ohne', 'zu'),
#  ('ohne', 'zu', 'bedenken'),
#  ('zu', 'bedenken', 'wie'),
#  ('bedenken', 'wie', 'in'),
#  ('wie', 'in', 'aller'),
#  ('in', 'aller', 'welt'),
#  ('aller', 'welt', 'sie'),
#  ('welt', 'sie', 'wieder'),
#  ('sie', 'wieder', 'herauskommen'),
#  ('wieder', 'herauskommen', 'könnte'),
#  ('herauskommen', 'könnte', 'der'),
#  ('könnte', 'der', 'eingang'),
#  ('der', 'eingang', 'zum'),
#  ('eingang', 'zum', 'kaninchenbau'),
#  ('zum', 'kaninchenbau', 'lief'),
#  ('kaninchenbau', 'lief', 'erst'),
#  ('lief', 'erst', 'geradeaus'),
#  ('erst', 'geradeaus', 'wie'),
#  ('geradeaus', 'wie', 'ein'),
#  ('wie', 'ein', 'tunnel'),
#  ('ein', 'tunnel', 'und'),
#  ('tunnel', 'und', 'ging'),
#  ('und', 'ging', 'dann'),
#  ('ging', 'dann', 'plötzlich'),
#  ('dann', 'plötzlich', 'abwärts'),
#  ('plötzlich', 'abwärts', 'ehe'),
#  ('abwärts', 'ehe', 'alice'),
#  ('ehe', 'alice', 'noch'),
#  ('alice', 'noch', 'den'),
#  ('noch', 'den', 'ge'),
#  ('den', 'ge', 'danken'),
#  ('ge', 'danken', 'fassen'),
#  ('danken', 'fassen', 'konnte'),
#  ('fassen', 'konnte', 'sich'),
#  ('konnte', 'sich', 'schnell'),
#  ('sich', 'schnell', 'festzuhalten'),
#  ('schnell', 'festzuhalten', 'fühlte'),
#  ('festzuhalten', 'fühlte', 'sie'),
#  ('fühlte', 'sie', 'schon'),
#  ('sie', 'schon', 'daß'),
#  ('schon', 'daß', 'sie'),
#  ('daß', 'sie', 'fiel'),
#  ('sie', 'fiel', 'wie'),
#  ('fiel', 'wie', 'es'),
#  ('wie', 'es', 'schien'),
#  ('es', 'schien', 'in'),
#  ('schien', 'in', 'einen'),
#  ('in', 'einen', 'tiefen'),
#  ('einen', 'tiefen', 'tiefen'),
#  ('tiefen', 'tiefen', 'brunnen'),
#  ('tiefen', 'brunnen', 'entweder'),
#  ('brunnen', 'entweder', 'mußte'),
#  ('entweder', 'mußte', 'der'),
#  ('mußte', 'der', 'brunnen'),
#  ('der', 'brunnen', 'sehr'),
#  ('brunnen', 'sehr', 'tief'),
#  ('sehr', 'tief', 'sein'),
#  ('tief', 'sein', 'oder'),
#  ('sein', 'oder', 'sie'),
#  ('oder', 'sie', 'fiel'),
#  ('sie', 'fiel', 'sehr'),
#  ('fiel', 'sehr', 'langsam'),
#  ('sehr', 'langsam', 'denn'),
#  ('langsam', 'denn', 'sie'),
#  ('denn', 'sie', 'hatte'),
#  ('sie', 'hatte', 'zeit'),
#  ('hatte', 'zeit', 'genug'),
#  ('zeit', 'genug', 'sich'),
#  ('genug', 'sich', 'beim'),
#  ('sich', 'beim', 'fallen'),
#  ('beim', 'fallen', 'um'),
#  ('fallen', 'um', 'zusehen'),
#  ('um', 'zusehen', 'und'),
#  ('zusehen', 'und', 'sich'),
#  ('und', 'sich', 'zu'),
#  ('sich', 'zu', 'wundern'),
#  ('zu', 'wundern', 'was'),
#  ('wundern', 'was', 'nun'),
#  ('was', 'nun', 'wohl'),
#  ('nun', 'wohl', 'geschehen'),
#  ('wohl', 'geschehen', 'würde'),
#  ('geschehen', 'würde', 'zuerst'),
#  ('würde', 'zuerst', 'versuchte'),
#  ('zuerst', 'versuchte', 'sie'),
#  ('versuchte', 'sie', 'hinunter'),
#  ('sie', 'hinunter', 'zu'),
#  ('hinunter', 'zu', 'sehen'),
#  ('zu', 'sehen', 'um'),
#  ('sehen', 'um', 'zu'),
#  ('um', 'zu', 'wissen'),
#  ('zu', 'wissen', 'wohin'),
#  ('wissen', 'wohin', 'sie'),
#  ('wohin', 'sie', 'käme'),
#  ('sie', 'käme', 'aber'),
#  ('käme', 'aber', 'es'),
#  ('aber', 'es', 'war'),
#  ('es', 'war', 'zu'),
#  ('war', 'zu', 'dunkel'),
#  ('zu', 'dunkel', 'etwas'),
#  ('dunkel', 'etwas', 'zu'),
#  ('etwas', 'zu', 'erkennen'),
#  ('zu', 'erkennen', 'da'),
#  ('erkennen', 'da', 'besah'),
#  ('da', 'besah', 'sie'),
#  ('besah', 'sie', 'die'),
#  ('sie', 'die', 'wände'),
#  ('die', 'wände', 'des'),
#  ('wände', 'des', 'brunnens'),
#  ('des', 'brunnens', 'und'),
#  ('brunnens', 'und', 'bemerkte'),
#  ('und', 'bemerkte', 'daß'),
#  ('bemerkte', 'daß', 'sie'),
#  ('daß', 'sie', 'mit'),
#  ('sie', 'mit', 'küchenschrän'),
#  ('mit', 'küchenschrän', 'ken'),
#  ('küchenschrän', 'ken', 'und'),
#  ('ken', 'und', 'bücherbrettern'),
#  ('und', 'bücherbrettern', 'bedeckt'),
#  ('bücherbrettern', 'bedeckt', 'waren'),
#  ('bedeckt', 'waren', 'hier'),
#  ('waren', 'hier', 'und'),
#  ('hier', 'und', 'da'),
#  ('und', 'da', 'erblickte'),
#  ('da', 'erblickte', 'sie'),
#  ('erblickte', 'sie', 'landkarten'),
#  ('sie', 'landkarten', 'und'),
#  ('landkarten', 'und', 'bilder'),
#  ('und', 'bilder', 'an'),
#  ('bilder', 'an', 'haken'),
#  ('an', 'haken', 'aufgehängt'),
#  ('haken', 'aufgehängt', 'sie'),
#  ('aufgehängt', 'sie', 'nahm'),
#  ('sie', 'nahm', 'im'),
#  ('nahm', 'im', 'vor'),
#  ('im', 'vor', 'beifallen'),
#  ('vor', 'beifallen', 'von'),
#  ('beifallen', 'von', 'einem'),
#  ('von', 'einem', 'der'),
#  ('einem', 'der', 'bretter'),
#  ('der', 'bretter', 'ein'),
#  ('bretter', 'ein', 'töpfchen'),
#  ('ein', 'töpfchen', 'mit'),
#  ('töpfchen', 'mit', 'der'),
#  ('mit', 'der', 'aufschrift'),
#  ('der', 'aufschrift', 'eingemachte'),
#  ('aufschrift', 'eingemachte', 'apfelsinen'),
#  ('eingemachte', 'apfelsinen', 'aber'),
#  ('apfelsinen', 'aber', 'zu'),
#  ('aber', 'zu', 'ihrem'),
#  ('zu', 'ihrem', 'großen'),
#  ('ihrem', 'großen', 'verdruß'),
#  ('großen', 'verdruß', 'war'),
#  ('verdruß', 'war', 'es'),
#  ('war', 'es', 'leer'),
#  ('es', 'leer', 'sie'),
#  ('leer', 'sie', 'wollte'),
#  ('sie', 'wollte', 'es'),
#  ('wollte', 'es', 'nicht'),
#  ('es', 'nicht', 'fallen'),
#  ('nicht', 'fallen', 'lassen'),
#  ('fallen', 'lassen', 'aus'),
#  ('lassen', 'aus', 'furcht'),
#  ('aus', 'furcht', 'jemand'),
#  ('furcht', 'jemand', 'unter'),
#  ('jemand', 'unter', 'sich'),
#  ('unter', 'sich', 'zu'),
#  ('sich', 'zu', 'tödten'),
#  ('zu', 'tödten', 'und'),
#  ('tödten', 'und', 'es'),
#  ('und', 'es', 'gelang'),
#  ('es', 'gelang', 'ihr'),
#  ('gelang', 'ihr', 'es'),
#  ('ihr', 'es', 'in'),
#  ('es', 'in', 'einen'),
#  ('in', 'einen', 'andern'),
#  ('einen', 'andern', 'schrank'),
#  ('andern', 'schrank', 'an'),
#  ('schrank', 'an', 'dem'),
#  ('an', 'dem', 'sie'),
#  ('dem', 'sie', 'vorbeikam'),
#  ('sie', 'vorbeikam', 'zu'),
#  ('vorbeikam', 'zu', 'schieben'),
#  ('zu', 'schieben', 'nun'),
#  ('schieben', 'nun', 'dachte'),
#  ('nun', 'dachte', 'alice'),
#  ('dachte', 'alice', 'bei'),
#  ('alice', 'bei', 'sich'),
#  ('bei', 'sich', 'nach'),
#  ('sich', 'nach', 'einem'),
#  ('nach', 'einem', 'solchen'),
#  ('einem', 'solchen', 'fall'),
#  ('solchen', 'fall', 'werde'),
#  ('fall', 'werde', 'ich'),
#  ('werde', 'ich', 'mir'),
#  ('ich', 'mir', 'nichts'),
#  ('mir', 'nichts', 'daraus'),
#  ('nichts', 'daraus', 'machen'),
#  ('daraus', 'machen', 'wenn'),
#  ('machen', 'wenn', 'ich'),
#  ('wenn', 'ich', 'die'),
#  ('ich', 'die', 'treppe'),
#  ('die', 'treppe', 'hin'),
#  ('treppe', 'hin', 'unter'),
#  ('hin', 'unter', 'stolpere'),
#  ('unter', 'stolpere', 'wie'),
#  ('stolpere', 'wie', 'muthig'),
#  ('wie', 'muthig', 'sie'),
#  ('muthig', 'sie', 'mich'),
#  ('sie', 'mich', 'zu'),
#  ('mich', 'zu', 'haus'),
#  ('zu', 'haus', 'finden'),
#  ('haus', 'finden', 'werden'),
#  ('finden', 'werden', 'ich'),
#  ('werden', 'ich', 'würde'),
#  ('ich', 'würde', 'nicht'),
#  ('würde', 'nicht', 'viel'),
#  ('nicht', 'viel', 'redens'),
#  ('viel', 'redens', 'machen'),
#  ('redens', 'machen', 'wenn'),
#  ('machen', 'wenn', 'ich'),
#  ('wenn', 'ich', 'selbst'),
#  ('ich', 'selbst', 'von'),
#  ('selbst', 'von', 'der'),
#  ('von', 'der', 'dach'),
#  ('der', 'dach', 'spitze'),
#  ('dach', 'spitze', 'hinunter'),
#  ('spitze', 'hinunter', 'fiele'),
#  ('hinunter', 'fiele', 'was'),
#  ('fiele', 'was', 'sehr'),
#  ('was', 'sehr', 'wahrscheinlich'),
#  ('sehr', 'wahrscheinlich', 'war'),
#  ('wahrscheinlich', 'war', '9'),
#  ('war', '9', 'hinunter'),
#  ('9', 'hinunter', 'hinunter'),
#  ('hinunter', 'hinunter', 'hinunter'),
#  ('hinunter', 'hinunter', 'wollte'),
#  ('hinunter', 'wollte', 'denn'),
#  ('wollte', 'denn', 'der'),
#  ('denn', 'der', 'fall'),
#  ('der', 'fall', 'nie'),
#  ('fall', 'nie', 'endi'),
#  ('nie', 'endi', 'gen'),
#  ('endi', 'gen', 'wie'),
#  ('gen', 'wie', 'viele'),
#  ('wie', 'viele', 'meilen'),
#  ('viele', 'meilen', 'ich'),
#  ('meilen', 'ich', 'wohl'),
#  ('ich', 'wohl', 'jetzt'),
#  ('wohl', 'jetzt', 'gefallen'),
#  ('jetzt', 'gefallen', 'bin'),
#  ('gefallen', 'bin', 'sagte'),
#  ('bin', 'sagte', 'sie'),
#  ('sagte', 'sie', 'laut'),
#  ('sie', 'laut', 'ich'),
#  ('laut', 'ich', 'muß'),
#  ('ich', 'muß', 'ungefähr'),
#  ('muß', 'ungefähr', 'am'),
#  ('ungefähr', 'am', 'mittelpunkt'),
#  ('am', 'mittelpunkt', 'der'),
#  ('mittelpunkt', 'der', 'erde'),
#  ('der', 'erde', 'sein'),
#  ('erde', 'sein', 'laß'),
#  ('sein', 'laß', 'sehen'),
#  ('laß', 'sehen', 'das'),
#  ('sehen', 'das', 'wären'),
#  ('das', 'wären', 'achthundert'),
#  ('wären', 'achthundert', 'und'),
#  ('achthundert', 'und', 'funfzig'),
#  ('und', 'funfzig', 'meilen'),
#  ('funfzig', 'meilen', 'glaube'),
#  ('meilen', 'glaube', 'ich'),
#  ('glaube', 'ich', 'denn'),
#  ('ich', 'denn', 'ihr'),
#  ('denn', 'ihr', 'müßt'),
#  ('ihr', 'müßt', 'wissen'),
#  ('müßt', 'wissen', 'alice'),
#  ('wissen', 'alice', 'hatte'),
#  ('alice', 'hatte', 'dergleichen'),
#  ('hatte', 'dergleichen', 'in'),
#  ('dergleichen', 'in', 'der'),
#  ('in', 'der', 'schule'),
#  ('der', 'schule', 'gelernt'),
#  ('schule', 'gelernt', 'und'),
#  ('gelernt', 'und', 'obgleich'),
#  ('und', 'obgleich', 'dies'),
#  ('obgleich', 'dies', 'keine'),
#  ('dies', 'keine', 'sehr'),
#  ('keine', 'sehr', 'gute'),
#  ('sehr', 'gute', 'gelegenheit'),
#  ('gute', 'gelegenheit', 'war'),
#  ('gelegenheit', 'war', 'ihre'),
#  ('war', 'ihre', 'kenntnisse'),
#  ('ihre', 'kenntnisse', 'zu'),
#  ('kenntnisse', 'zu', 'zeigen'),
#  ('zu', 'zeigen', 'da'),
#  ('zeigen', 'da', 'niemand'),
#  ('da', 'niemand', 'zum'),
#  ('niemand', 'zum', 'zuhören'),
#  ('zum', 'zuhören', 'da'),
#  ('zuhören', 'da', 'war'),
#  ('da', 'war', 'so'),
#  ('war', 'so', 'übte'),
#  ('so', 'übte', 'sie'),
#  ('übte', 'sie', 'es'),
#  ('sie', 'es', 'sich'),
#  ('es', 'sich', 'doch'),
#  ('sich', 'doch', 'dabei'),
#  ('doch', 'dabei', 'ein'),
#  ('dabei', 'ein', 'ja'),
#  ('ein', 'ja', 'das'),
#  ('ja', 'das', 'ist'),
#  ('das', 'ist', 'ungefähr'),
#  ('ist', 'ungefähr', 'die'),
#  ('ungefähr', 'die', 'entfernung'),
#  ('die', 'entfernung', 'aber'),
#  ('entfernung', 'aber', 'zu'),
#  ('aber', 'zu', 'wel'),
#  ('zu', 'wel', 'chem'),
#  ('wel', 'chem', 'länge'),
#  ('chem', 'länge', 'und'),
#  ('länge', 'und', 'breitegrade'),
#  ('und', 'breitegrade', 'ich'),
#  ('breitegrade', 'ich', 'wohl'),
#  ('ich', 'wohl', 'gekommen'),
#  ('wohl', 'gekommen', 'sein'),
#  ('gekommen', 'sein', 'mag'),
#  ('sein', 'mag', 'alice'),
#  ('mag', 'alice', 'hatte'),
#  ('alice', 'hatte', 'nicht'),
#  ('hatte', 'nicht', 'den'),
#  ('nicht', 'den', 'geringsten'),
#  ('den', 'geringsten', 'begriff'),
#  ('geringsten', 'begriff', 'was'),
#  ('begriff', 'was', 'weder'),
#  ('was', 'weder', 'längegrad'),
#  ('weder', 'längegrad', 'noch'),
#  ('längegrad', 'noch', 'breitegrad'),
#  ('noch', 'breitegrad', 'war'),
#  ('breitegrad', 'war', 'doch'),
#  ('war', 'doch', 'klangen'),
#  ('doch', 'klangen', 'ihr'),
#  ('klangen', 'ihr', 'die'),
#  ('ihr', 'die', 'worte'),
#  ('die', 'worte', 'großartig'),
#  ('worte', 'großartig', 'und'),
#  ('großartig', 'und', 'nett'),
#  ('und', 'nett', 'zu'),
#  ('nett', 'zu', 'sagen'),
#  ('zu', 'sagen', 'bald'),
#  ('sagen', 'bald', 'fing'),
#  ('bald', 'fing', 'sie'),
#  ('fing', 'sie', 'wieder'),
#  ('sie', 'wieder', 'an'),
#  ('wieder', 'an', 'ob'),
#  ('an', 'ob', 'ich'),
#  ('ob', 'ich', 'wohl'),
#  ('ich', 'wohl', 'ganz'),
#  ('wohl', 'ganz', 'durch'),
#  ('ganz', 'durch', 'die'),
#  ('durch', 'die', 'erde'),
#  ('die', 'erde', 'fallen'),
#  ('erde', 'fallen', 'werde'),
#  ('fallen', 'werde', 'wie'),
#  ('werde', 'wie', 'komisch'),
#  ('wie', 'komisch', 'das'),
#  ('komisch', 'das', 'sein'),
#  ('das', 'sein', 'wird'),
#  ('sein', 'wird', 'bei'),
#  ('wird', 'bei', 'den'),
#  ('bei', 'den', 'leuten'),
#  ('den', 'leuten', 'heraus'),
#  ('leuten', 'heraus', 'zu'),
#  ('heraus', 'zu', 'kommen'),
#  ('zu', 'kommen', 'die'),
#  ('kommen', 'die', 'auf'),
#  ('die', 'auf', 'dem'),
#  ('auf', 'dem', 'kopfe'),
#  ('dem', 'kopfe', 'gehen'),
#  ('kopfe', 'gehen', 'die'),
#  ('gehen', 'die', 'antipathien'),
#  ('die', 'antipathien', 'glaube'),
#  ('antipathien', 'glaube', 'ich'),
#  ('glaube', 'ich', 'diesmal'),
#  ('ich', 'diesmal', 'war'),
#  ('diesmal', 'war', 'es'),
#  ('war', 'es', 'ihr'),
#  ('es', 'ihr', 'ganz'),
#  ('ihr', 'ganz', 'lieb'),
#  ('ganz', 'lieb', 'daß'),
#  ('lieb', 'daß', 'niemand'),
#  ('daß', 'niemand', 'zuhörte'),
#  ('niemand', 'zuhörte', 'denn'),
#  ('zuhörte', 'denn', 'das'),
#  ('denn', 'das', 'wort'),
#  ('das', 'wort', 'klang'),
#  ('wort', 'klang', 'ihr'),
#  ('klang', 'ihr', 'gar'),
#  ('ihr', 'gar', 'nicht'),
#  ('gar', 'nicht', 'recht'),
#  ('nicht', 'recht', 'aber'),
#  ...]

# %% [markdown]
# Get the frequencey of each sequence

# %%
collections.Counter(ngrams)
# Out:
# Counter({('alice', 's', 'abenteuer'): 1,
#          ('s', 'abenteuer', 'im'): 1,
#          ('abenteuer', 'im', 'wunderland'): 1,
#          ('im', 'wunderland', 'von'): 1,
#          ('wunderland', 'von', 'lewis'): 1,
#          ('von', 'lewis', 'carroll'): 1,
#          ('lewis', 'carroll', 'aus'): 1,
#          ('carroll', 'aus', 'dem'): 1,
#          ('aus', 'dem', 'englischen'): 1,
#          ('dem', 'englischen', 'von'): 1,
#          ('englischen', 'von', 'antonie'): 1,
#          ('von', 'antonie', 'zimmermann'): 1,
#          ('antonie', 'zimmermann', 'autorisierte'): 1,
#          ('zimmermann', 'autorisierte', 'ausgabe'): 1,
#          ('autorisierte', 'ausgabe', 'mit'): 1,
#          ('ausgabe', 'mit', 'den'): 1,
#          ('mit', 'den', 'illustrationen'): 1,
#          ('den', 'illustrationen', 'von'): 1,
#          ('illustrationen', 'von', 'john'): 1,
#          ('von', 'john', 'tenniel'): 1,
#          ('john', 'tenniel', 'koloriert'): 1,
#          ('tenniel', 'koloriert', 'von'): 1,
#          ('koloriert', 'von', 'günter'): 1,
#          ('von', 'günter', 'jürgensmeier'): 1,
#          ('günter', 'jürgensmeier', 'für'): 1,
#          ('jürgensmeier', 'für', 'luzie'): 1,
#          ('für', 'luzie', 'johann'): 1,
#          ('luzie', 'johann', 'friedrich'): 1,
#          ('johann', 'friedrich', 'hartknoch'): 1,
#          ('friedrich', 'hartknoch', 'leipzig'): 1,
#          ('hartknoch', 'leipzig', '1869'): 1,
#          ('leipzig', '1869', 'inhalt'): 1,
#          ('1869', 'inhalt', '01'): 1,
#          ('inhalt', '01', 'hinunter'): 1,
#          ('01', 'hinunter', 'in'): 1,
#          ('hinunter', 'in', 'den'): 2,
#          ('in', 'den', 'kaninchenbau'): 3,
#          ('den', 'kaninchenbau', '02'): 1,
#          ('kaninchenbau', '02', 'der'): 1,
#          ('02', 'der', 'thränenpfuhl'): 1,
#          ('der', 'thränenpfuhl', '03'): 1,
#          ('thränenpfuhl', '03', 'caucus'): 1,
#          ('03', 'caucus', 'rennen'): 1,
#          ('caucus', 'rennen', 'und'): 2,
#          ('rennen', 'und', 'was'): 2,
#          ('und', 'was', 'daraus'): 2,
#          ('was', 'daraus', 'wird'): 2,
#          ('daraus', 'wird', '04'): 1,
#          ('wird', '04', 'die'): 1,
#          ('04', 'die', 'wohnung'): 1,
#          ('die', 'wohnung', 'des'): 2,
#          ('wohnung', 'des', 'kaninchens'): 2,
#          ('des', 'kaninchens', '05'): 1,
#          ('kaninchens', '05', 'guter'): 1,
#          ('05', 'guter', 'rath'): 1,
#          ('guter', 'rath', 'von'): 2,
#          ('rath', 'von', 'einer'): 2,
#          ('von', 'einer', 'raupe'): 2,
#          ('einer', 'raupe', '06'): 1,
#          ('raupe', '06', 'ferkel'): 1,
#          ('06', 'ferkel', 'und'): 1,
#          ('ferkel', 'und', 'pfeffer'): 2,
#          ('und', 'pfeffer', '07'): 1,
#          ('pfeffer', '07', 'die'): 1,
#          ('07', 'die', 'tolle'): 1,
#          ('die', 'tolle', 'theegesellschaft'): 2,
#          ('tolle', 'theegesellschaft', '08'): 1,
#          ('theegesellschaft', '08', 'das'): 1,
#          ('08', 'das', 'croquetfeld'): 1,
#          ('das', 'croquetfeld', 'der'): 2,
#          ('croquetfeld', 'der', 'königin'): 2,
#          ('der', 'königin', '09'): 1,
#          ('königin', '09', 'die'): 1,
#          ('09', 'die', 'geschichte'): 1,
#          ('die', 'geschichte', 'der'): 2,
#          ('geschichte', 'der', 'falschen'): 2,
#          ('der', 'falschen', 'schildkröte'): 6,
#          ('falschen', 'schildkröte', '10'): 1,
#          ('schildkröte', '10', 'das'): 1,
#          ('10', 'das', 'hummerballet'): 1,
#          ('das', 'hummerballet', '11'): 1,
#          ('hummerballet', '11', 'wer'): 1,
#          ('11', 'wer', 'hat'): 1,
#          ('wer', 'hat', 'die'): 2,
#          ('hat', 'die', 'kuchen'): 2,
#          ('die', 'kuchen', 'gestohlen'): 2,
#          ('kuchen', 'gestohlen', '12'): 1,
#          ('gestohlen', '12', 'alice'): 1,
#          ('12', 'alice', 'ist'): 1,
#          ('alice', 'ist', 'die'): 2,
#          ('ist', 'die', 'klügste'): 2,
#          ('die', 'klügste', '7'): 1,
#          ('klügste', '7', '15'): 1,
#          ('7', '15', '23'): 1,
#          ('15', '23', '31'): 1,
#          ('23', '31', '41'): 1,
#          ('31', '41', '51'): 1,
#          ('41', '51', '62'): 1,
#          ('51', '62', '72'): 1,
#          ('62', '72', '82'): 1,
#          ('72', '82', '92'): 1,
#          ('82', '92', '100'): 1,
#          ('92', '100', '108'): 1,
#          ('100', '108', 'der'): 1,
#          ('108', 'der', 'verfasser'): 1,
#          ('der', 'verfasser', 'wünscht'): 1,
#          ('verfasser', 'wünscht', 'hiermit'): 1,
#          ('wünscht', 'hiermit', 'seine'): 1,
#          ('hiermit', 'seine', 'anerkennung'): 1,
#          ('seine', 'anerkennung', 'gegen'): 1,
#          ('anerkennung', 'gegen', 'die'): 1,
#          ('gegen', 'die', 'übersetzerin'): 1,
#          ('die', 'übersetzerin', 'auszusprechen'): 1,
#          ('übersetzerin', 'auszusprechen', 'die'): 1,
#          ('auszusprechen', 'die', 'einige'): 1,
#          ('die', 'einige', 'eingestreute'): 1,
#          ('einige', 'eingestreute', 'parodien'): 1,
#          ('eingestreute', 'parodien', 'englischer'): 1,
#          ('parodien', 'englischer', 'kinderlieder'): 1,
#          ('englischer', 'kinderlieder', 'welche'): 1,
#          ('kinderlieder', 'welche', 'der'): 1,
#          ('welche', 'der', 'deutschen'): 1,
#          ('der', 'deutschen', 'jugend'): 1,
#          ('deutschen', 'jugend', 'unver'): 1,
#          ('jugend', 'unver', 'ständlich'): 1,
#          ('unver', 'ständlich', 'gewesen'): 1,
#          ('ständlich', 'gewesen', 'wären'): 1,
#          ('gewesen', 'wären', 'durch'): 1,
#          ('wären', 'durch', 'dergleichen'): 1,
#          ('durch', 'dergleichen', 'von'): 1,
#          ('dergleichen', 'von', 'bekannten'): 1,
#          ('von', 'bekannten', 'deutschen'): 1,
#          ('bekannten', 'deutschen', 'gedichten'): 1,
#          ('deutschen', 'gedichten', 'ersetzt'): 1,
#          ('gedichten', 'ersetzt', 'hat'): 1,
#          ('ersetzt', 'hat', 'ebenso'): 1,
#          ('hat', 'ebenso', 'sind'): 1,
#          ('ebenso', 'sind', 'für'): 1,
#          ('sind', 'für', 'die'): 1,
#          ('für', 'die', 'oft'): 1,
#          ('die', 'oft', 'unüber'): 1,
#          ('oft', 'unüber', 'setzbaren'): 1,
#          ('unüber', 'setzbaren', 'englischen'): 1,
#          ('setzbaren', 'englischen', 'wortspiele'): 1,
#          ('englischen', 'wortspiele', 'passende'): 1,
#          ('wortspiele', 'passende', 'deutsche'): 1,
#          ('passende', 'deutsche', 'eingescho'): 1,
#          ('deutsche', 'eingescho', 'ben'): 1,
#          ('eingescho', 'ben', 'worden'): 1,
#          ('ben', 'worden', 'welche'): 1,
#          ('worden', 'welche', 'das'): 1,
#          ('welche', 'das', 'buch'): 1,
#          ('das', 'buch', 'allein'): 1,
#          ('buch', 'allein', 'der'): 1,
#          ('allein', 'der', 'gewandtheit'): 1,
#          ('der', 'gewandtheit', 'der'): 1,
#          ('gewandtheit', 'der', 'über'): 1,
#          ('der', 'über', 'setzerin'): 1,
#          ('über', 'setzerin', 'verdankt'): 1,
#          ('setzerin', 'verdankt', 'o'): 1,
#          ('verdankt', 'o', 'schöner'): 1,
#          ('o', 'schöner', 'goldner'): 1,
#          ('schöner', 'goldner', 'nachmittag'): 1,
#          ('goldner', 'nachmittag', 'wo'): 1,
#          ('nachmittag', 'wo', 'flut'): 1,
#          ('wo', 'flut', 'und'): 1,
#          ('flut', 'und', 'himmel'): 1,
#          ('und', 'himmel', 'lacht'): 1,
#          ('himmel', 'lacht', 'von'): 1,
#          ('lacht', 'von', 'schwacher'): 1,
#          ('von', 'schwacher', 'kindeshand'): 1,
#          ('schwacher', 'kindeshand', 'bewegt'): 1,
#          ('kindeshand', 'bewegt', 'die'): 1,
#          ('bewegt', 'die', 'ruder'): 1,
#          ('die', 'ruder', 'plätschern'): 1,
#          ('ruder', 'plätschern', 'sacht'): 1,
#          ('plätschern', 'sacht', 'das'): 1,
#          ('sacht', 'das', 'steuer'): 1,
#          ('das', 'steuer', 'hält'): 1,
#          ('steuer', 'hält', 'ein'): 1,
#          ('hält', 'ein', 'kindesarm'): 1,
#          ('ein', 'kindesarm', 'und'): 1,
#          ('kindesarm', 'und', 'lenket'): 1,
#          ('und', 'lenket', 'unsre'): 1,
#          ('lenket', 'unsre', 'fahrt'): 1,
#          ('unsre', 'fahrt', 'so'): 1,
#          ('fahrt', 'so', 'fuhren'): 1,
#          ('so', 'fuhren', 'wir'): 1,
#          ('fuhren', 'wir', 'gemächlich'): 1,
#          ('wir', 'gemächlich', 'hin'): 1,
#          ('gemächlich', 'hin', 'auf'): 1,
#          ('hin', 'auf', 'träumerischen'): 1,
#          ('auf', 'träumerischen', 'wellen'): 1,
#          ('träumerischen', 'wellen', 'doch'): 1,
#          ('wellen', 'doch', 'ach'): 1,
#          ('doch', 'ach', 'die'): 1,
#          ('ach', 'die', 'drei'): 1,
#          ('die', 'drei', 'vereinten'): 1,
#          ('drei', 'vereinten', 'sich'): 1,
#          ('vereinten', 'sich', 'den'): 1,
#          ('sich', 'den', 'müden'): 1,
#          ('den', 'müden', 'freund'): 1,
#          ('müden', 'freund', 'zu'): 1,
#          ('freund', 'zu', 'quälen'): 1,
#          ('zu', 'quälen', 'sie'): 1,
#          ('quälen', 'sie', 'trieben'): 1,
#          ('sie', 'trieben', 'ihn'): 1,
#          ('trieben', 'ihn', 'sie'): 1,
#          ('ihn', 'sie', 'drängten'): 1,
#          ('sie', 'drängten', 'ihn'): 1,
#          ('drängten', 'ihn', 'ein'): 1,
#          ('ihn', 'ein', 'mährchen'): 1,
#          ('ein', 'mährchen', 'zu'): 1,
#          ('mährchen', 'zu', 'erzählen'): 1,
#          ('zu', 'erzählen', 'die'): 1,
#          ('erzählen', 'die', 'erste'): 1,
#          ('die', 'erste', 'gab'): 1,
#          ('erste', 'gab', 's'): 1,
#          ('gab', 's', 'commandowort'): 1,
#          ('s', 'commandowort', 'o'): 1,
#          ('commandowort', 'o', 'schnell'): 1,
#          ('o', 'schnell', 'o'): 1,
#          ('schnell', 'o', 'fange'): 1,
#          ('o', 'fange', 'an'): 1,
#          ('fange', 'an', 'und'): 1,
#          ('an', 'und', 'mach'): 1,
#          ('und', 'mach', 'es'): 1,
#          ('mach', 'es', 'so'): 1,
#          ('es', 'so', 'die'): 1,
#          ('so', 'die', 'zweite'): 1,
#          ('die', 'zweite', 'bat'): 1,
#          ('zweite', 'bat', 'daß'): 1,
#          ('bat', 'daß', 'man'): 1,
#          ('daß', 'man', 'recht'): 1,
#          ('man', 'recht', 'lachen'): 1,
#          ('recht', 'lachen', 'kann'): 1,
#          ('lachen', 'kann', 'die'): 1,
#          ('kann', 'die', 'dritte'): 1,
#          ('die', 'dritte', 'ließ'): 1,
#          ('dritte', 'ließ', 'ihm'): 1,
#          ('ließ', 'ihm', 'keine'): 1,
#          ('ihm', 'keine', 'ruh'): 1,
#          ('keine', 'ruh', 'mit'): 1,
#          ('ruh', 'mit', 'wie'): 1,
#          ('mit', 'wie', 'und'): 1,
#          ('wie', 'und', 'wo'): 1,
#          ('und', 'wo', 'und'): 1,
#          ('wo', 'und', 'wann'): 1,
#          ('und', 'wann', 'jetzt'): 1,
#          ('wann', 'jetzt', 'lauschen'): 1,
#          ('jetzt', 'lauschen', 'sie'): 1,
#          ('lauschen', 'sie', 'vom'): 1,
#          ('sie', 'vom', 'zauberland'): 1,
#          ('vom', 'zauberland', 'der'): 1,
#          ('zauberland', 'der', 'wunderbaren'): 1,
#          ('der', 'wunderbaren', 'mähr'): 1,
#          ('wunderbaren', 'mähr', 'mit'): 1,
#          ('mähr', 'mit', 'thier'): 1,
#          ('mit', 'thier', 'und'): 1,
#          ('thier', 'und', 'vogel'): 1,
#          ('und', 'vogel', 'sind'): 1,
#          ('vogel', 'sind', 'sie'): 1,
#          ('sind', 'sie', 'bald'): 1,
#          ('sie', 'bald', 'in'): 1,
#          ('bald', 'in', 'freundlichem'): 1,
#          ('in', 'freundlichem', 'verkehr'): 1,
#          ('freundlichem', 'verkehr', 'und'): 1,
#          ('verkehr', 'und', 'fühlen'): 1,
#          ('und', 'fühlen', 'sich'): 1,
#          ('fühlen', 'sich', 'so'): 1,
#          ('sich', 'so', 'heimisch'): 1,
#          ('so', 'heimisch', 'dort'): 1,
#          ('heimisch', 'dort', 'als'): 1,
#          ('dort', 'als', 'ob'): 1,
#          ('als', 'ob', 'es'): 4,
#          ('ob', 'es', 'wahrheit'): 1,
#          ('es', 'wahrheit', 'wär'): 1,
#          ('wahrheit', 'wär', 'und'): 1,
#          ('wär', 'und', 'jedes'): 1,
#          ('und', 'jedes', 'mal'): 1,
#          ('jedes', 'mal', 'wenn'): 1,
#          ('mal', 'wenn', 'fantasie'): 1,
#          ('wenn', 'fantasie', 'dem'): 1,
#          ('fantasie', 'dem', 'freunde'): 1,
#          ('dem', 'freunde', 'ganz'): 1,
#          ('freunde', 'ganz', 'versiegt'): 1,
#          ('ganz', 'versiegt', 'das'): 1,
#          ('versiegt', 'das', 'übrige'): 1,
#          ('das', 'übrige', 'ein'): 1,
#          ('übrige', 'ein', 'ander'): 1,
#          ('ein', 'ander', 'mal'): 2,
#          ('ander', 'mal', 'o'): 1,
#          ('mal', 'o', 'nein'): 1,
#          ('o', 'nein', 'sie'): 1,
#          ('nein', 'sie', 'leiden'): 1,
#          ('sie', 'leiden', 's'): 1,
#          ('leiden', 's', 'nicht'): 1,
#          ('s', 'nicht', 'es'): 1,
#          ('nicht', 'es', 'ist'): 1,
#          ('es', 'ist', 'ja'): 3,
#          ('ist', 'ja', 'schon'): 1,
#          ('ja', 'schon', 'ein'): 1,
#          ('schon', 'ein', 'ander'): 1,
#          ('ander', 'mal', 'so'): 1,
#          ('mal', 'so', 'rufen'): 1,
#          ('so', 'rufen', 'sie'): 1,
#          ('rufen', 'sie', 'vergnügt'): 1,
#          ('sie', 'vergnügt', 'so'): 1,
#          ('vergnügt', 'so', 'ward'): 1,
#          ('so', 'ward', 'vom'): 1,
#          ('ward', 'vom', 'schönen'): 1,
#          ('vom', 'schönen', 'wunderland'): 1,
#          ('schönen', 'wunderland', 'das'): 1,
#          ('wunderland', 'das', 'märchen'): 1,
#          ('das', 'märchen', 'ausgedacht'): 1,
#          ('märchen', 'ausgedacht', 'so'): 1,
#          ('ausgedacht', 'so', 'langsam'): 1,
#          ('so', 'langsam', 'stück'): 1,
#          ('langsam', 'stück', 'für'): 1,
#          ('stück', 'für', 'stück'): 1,
#          ('für', 'stück', 'erzählt'): 1,
#          ('stück', 'erzählt', 'beplaudert'): 1,
#          ('erzählt', 'beplaudert', 'und'): 1,
#          ('beplaudert', 'und', 'belacht'): 1,
#          ('und', 'belacht', 'und'): 1,
#          ('belacht', 'und', 'froh'): 1,
#          ('und', 'froh', 'als'): 1,
#          ('froh', 'als', 'es'): 1,
#          ('als', 'es', 'zu'): 1,
#          ('es', 'zu', 'ende'): 1,
#          ('zu', 'ende', 'war'): 2,
#          ('ende', 'war', 'der'): 1,
#          ('war', 'der', 'weg'): 1,
#          ('der', 'weg', 'nach'): 1,
#          ('weg', 'nach', 'haus'): 1,
#          ('nach', 'haus', 'gemacht'): 1,
#          ('haus', 'gemacht', 'alice'): 1,
#          ('gemacht', 'alice', 'o'): 1,
#          ('alice', 'o', 'nimm'): 1,
#          ('o', 'nimm', 'es'): 1,
#          ('nimm', 'es', 'freundlich'): 1,
#          ('es', 'freundlich', 'an'): 1,
#          ('freundlich', 'an', 'leg'): 1,
#          ('an', 'leg', 'es'): 1,
#          ('leg', 'es', 'mit'): 1,
#          ('es', 'mit', 'güt'): 1,
#          ('mit', 'güt', 'ger'): 1,
#          ('güt', 'ger', 'hand'): 1,
#          ('ger', 'hand', 'zum'): 1,
#          ('hand', 'zum', 'strauße'): 1,
#          ('zum', 'strauße', 'den'): 1,
#          ('strauße', 'den', 'erinnerung'): 1,
#          ('den', 'erinnerung', 'aus'): 1,
#          ('erinnerung', 'aus', 'kindheitsträumen'): 1,
#          ('aus', 'kindheitsträumen', 'band'): 1,
#          ('kindheitsträumen', 'band', 'gleich'): 1,
#          ('band', 'gleich', 'welken'): 1,
#          ('gleich', 'welken', 'blüthen'): 1,
#          ('welken', 'blüthen', 'mitgebracht'): 1,
#          ('blüthen', 'mitgebracht', 'aus'): 1,
#          ('mitgebracht', 'aus', 'liebem'): 1,
#          ('aus', 'liebem', 'fernen'): 1,
#          ('liebem', 'fernen', 'land'): 1,
#          ('fernen', 'land', 'erstes'): 1,
#          ('land', 'erstes', 'kapitel'): 1,
#          ('erstes', 'kapitel', 'hinunter'): 1,
#          ('kapitel', 'hinunter', 'in'): 1,
#          ('den', 'kaninchenbau', 'alice'): 1,
#          ('kaninchenbau', 'alice', 'fing'): 1,
#          ('alice', 'fing', 'an'): 2,
#          ('fing', 'an', 'sich'): 3,
#          ('an', 'sich', 'zu'): 4,
#          ('sich', 'zu', 'langweilen'): 1,
#          ('zu', 'langweilen', 'sie'): 1,
#          ('langweilen', 'sie', 'saß'): 1,
#          ('sie', 'saß', 'schon'): 1,
#          ('saß', 'schon', 'lange'): 1,
#          ('schon', 'lange', 'bei'): 1,
#          ('lange', 'bei', 'ihrer'): 1,
#          ('bei', 'ihrer', 'schwester'): 1,
#          ('ihrer', 'schwester', 'am'): 1,
#          ('schwester', 'am', 'ufer'): 1,
#          ('am', 'ufer', 'und'): 1,
#          ('ufer', 'und', 'hatte'): 1,
#          ('und', 'hatte', 'nichts'): 1,
#          ('hatte', 'nichts', 'zu'): 1,
#          ('nichts', 'zu', 'thun'): 3,
#          ('zu', 'thun', 'das'): 1,
#          ('thun', 'das', 'buch'): 1,
#          ('das', 'buch', 'das'): 1,
#          ('buch', 'das', 'ihre'): 1,
#          ('das', 'ihre', 'schwester'): 1,
#          ('ihre', 'schwester', 'las'): 1,
#          ('schwester', 'las', 'gefiel'): 1,
#          ('las', 'gefiel', 'ihr'): 1,
#          ('gefiel', 'ihr', 'nicht'): 1,
#          ('ihr', 'nicht', 'denn'): 1,
#          ('nicht', 'denn', 'es'): 1,
#          ('denn', 'es', 'waren'): 1,
#          ('es', 'waren', 'weder'): 1,
#          ('waren', 'weder', 'bilder'): 1,
#          ('weder', 'bilder', 'noch'): 1,
#          ('bilder', 'noch', 'gespräche'): 1,
#          ('noch', 'gespräche', 'darin'): 1,
#          ('gespräche', 'darin', 'und'): 1,
#          ('darin', 'und', 'was'): 1,
#          ('und', 'was', 'nützen'): 1,
#          ('was', 'nützen', 'bücher'): 1,
#          ('nützen', 'bücher', 'dachte'): 1,
#          ('bücher', 'dachte', 'alice'): 1,
#          ('dachte', 'alice', 'ohne'): 1,
#          ('alice', 'ohne', 'bilder'): 1,
#          ('ohne', 'bilder', 'und'): 1,
#          ('bilder', 'und', 'gespräche'): 1,
#          ('und', 'gespräche', 'sie'): 1,
#          ('gespräche', 'sie', 'überlegte'): 1,
#          ('sie', 'überlegte', 'sich'): 1,
#          ('überlegte', 'sich', 'eben'): 1,
#          ('sich', 'eben', 'so'): 1,
#          ('eben', 'so', 'gut'): 4,
#          ('so', 'gut', 'es'): 2,
#          ('gut', 'es', 'ging'): 1,
#          ('es', 'ging', 'denn'): 1,
#          ('ging', 'denn', 'sie'): 1,
#          ('denn', 'sie', 'war'): 3,
#          ('sie', 'war', 'schläf'): 1,
#          ('war', 'schläf', 'rig'): 1,
#          ('schläf', 'rig', 'und'): 1,
#          ('rig', 'und', 'dumm'): 1,
#          ('und', 'dumm', 'von'): 1,
#          ('dumm', 'von', 'der'): 1,
#          ('von', 'der', 'hitze'): 1,
#          ('der', 'hitze', 'ob'): 1,
#          ('hitze', 'ob', 'es'): 1,
#          ('ob', 'es', 'der'): 1,
#          ('es', 'der', 'mühe'): 1,
#          ('der', 'mühe', 'werth'): 3,
#          ('mühe', 'werth', 'sei'): 2,
#          ('werth', 'sei', 'aufzu'): 1,
#          ('sei', 'aufzu', 'stehen'): 1,
#          ('aufzu', 'stehen', 'und'): 1,
#          ('stehen', 'und', 'gänseblümchen'): 1,
#          ('und', 'gänseblümchen', 'zu'): 1,
#          ('gänseblümchen', 'zu', 'pflücken'): 1,
#          ('zu', 'pflücken', 'um'): 1,
#          ('pflücken', 'um', 'eine'): 1,
#          ('um', 'eine', 'kette'): 1,
#          ('eine', 'kette', 'damit'): 1,
#          ('kette', 'damit', 'zu'): 1,
#          ('damit', 'zu', 'machen'): 1,
#          ('zu', 'machen', 'als'): 1,
#          ('machen', 'als', 'plötzlich'): 1,
#          ('als', 'plötzlich', 'ein'): 2,
#          ('plötzlich', 'ein', 'weißes'): 1,
#          ('ein', 'weißes', 'kaninchen'): 1,
#          ('weißes', 'kaninchen', 'mit'): 1,
#          ('kaninchen', 'mit', 'rothen'): 1,
#          ('mit', 'rothen', 'augen'): 1,
#          ('rothen', 'augen', 'dicht'): 1,
#          ('augen', 'dicht', 'an'): 1,
#          ('dicht', 'an', 'ihr'): 1,
#          ('an', 'ihr', 'vorbeirannte'): 1,
#          ('ihr', 'vorbeirannte', '8'): 1,
#          ('vorbeirannte', '8', 'dies'): 1,
#          ('8', 'dies', 'war'): 1,
#          ('dies', 'war', 'grade'): 1,
#          ('war', 'grade', 'nicht'): 1,
#          ('grade', 'nicht', 'sehr'): 1,
#          ('nicht', 'sehr', 'merkwürdig'): 1,
#          ('sehr', 'merkwürdig', 'alice'): 1,
#          ('merkwürdig', 'alice', 'fand'): 1,
#          ('alice', 'fand', 'es'): 1,
#          ('fand', 'es', 'auch'): 1,
#          ('es', 'auch', 'nicht'): 2,
#          ('auch', 'nicht', 'sehr'): 1,
#          ('nicht', 'sehr', 'außerordentlich'): 1,
#          ('sehr', 'außerordentlich', 'daß'): 1,
#          ('außerordentlich', 'daß', 'sie'): 1,
#          ('daß', 'sie', 'das'): 3,
#          ('sie', 'das', 'kaninchen'): 1,
#          ('das', 'kaninchen', 'sagen'): 2,
#          ('kaninchen', 'sagen', 'hörte'): 1,
#          ('sagen', 'hörte', 'o'): 1,
#          ('hörte', 'o', 'weh'): 1,
#          ('o', 'weh', 'o'): 1,
#          ('weh', 'o', 'weh'): 1,
#          ('o', 'weh', 'ich'): 1,
#          ('weh', 'ich', 'werde'): 1,
#          ('ich', 'werde', 'zu'): 1,
#          ('werde', 'zu', 'spät'): 1,
#          ('zu', 'spät', 'kommen'): 1,
#          ('spät', 'kommen', 'als'): 1,
#          ('kommen', 'als', 'sie'): 1,
#          ('als', 'sie', 'es'): 3,
#          ('sie', 'es', 'später'): 1,
#          ('es', 'später', 'wieder'): 1,
#          ('später', 'wieder', 'überlegte'): 1,
#          ('wieder', 'überlegte', 'fiel'): 1,
#          ('überlegte', 'fiel', 'ihr'): 1,
#          ('fiel', 'ihr', 'ein'): 1,
#          ('ihr', 'ein', 'daß'): 1,
#          ('ein', 'daß', 'sie'): 3,
#          ('daß', 'sie', 'sich'): 6,
#          ('sie', 'sich', 'darüber'): 1,
#          ('sich', 'darüber', 'hätte'): 1,
#          ('darüber', 'hätte', 'wundern'): 1,
#          ('hätte', 'wundern', 'sollen'): 1,
#          ('wundern', 'sollen', 'doch'): 1,
#          ('sollen', 'doch', 'zur'): 1,
#          ('doch', 'zur', 'zeit'): 1,
#          ('zur', 'zeit', 'kam'): 1,
#          ('zeit', 'kam', 'es'): 1,
#          ('kam', 'es', 'ihr'): 2,
#          ('es', 'ihr', 'alles'): 1,
#          ('ihr', 'alles', 'ganz'): 1,
#          ('alles', 'ganz', 'natürlich'): 1,
#          ('ganz', 'natürlich', 'vor'): 2,
#          ('natürlich', 'vor', 'aber'): 1,
#          ('vor', 'aber', 'als'): 1,
#          ('aber', 'als', 'das'): 1,
#          ('als', 'das', 'kaninchen'): 2,
#          ('das', 'kaninchen', 'seine'): 1,
#          ('kaninchen', 'seine', 'uhr'): 1,
#          ('seine', 'uhr', 'aus'): 2,
#          ('uhr', 'aus', 'der'): 2,
#          ('aus', 'der', 'westentasche'): 1,
#          ('der', 'westentasche', 'zog'): 1,
#          ('westentasche', 'zog', 'nach'): 1,
#          ('zog', 'nach', 'der'): 1,
#          ('nach', 'der', 'zeit'): 1,
#          ('der', 'zeit', 'sah'): 1,
#          ('zeit', 'sah', 'und'): 1,
#          ('sah', 'und', 'eilig'): 1,
#          ('und', 'eilig', 'fortlief'): 1,
#          ('eilig', 'fortlief', 'sprang'): 1,
#          ('fortlief', 'sprang', 'alice'): 1,
#          ('sprang', 'alice', 'auf'): 1,
#          ('alice', 'auf', 'denn'): 1,
#          ('auf', 'denn', 'es'): 1,
#          ('denn', 'es', 'war'): 3,
#          ('es', 'war', 'ihr'): 2,
#          ('war', 'ihr', 'doch'): 1,
#          ('ihr', 'doch', 'noch'): 1,
#          ('doch', 'noch', 'nie'): 1,
#          ('noch', 'nie', 'vorgekommen'): 1,
#          ('nie', 'vorgekommen', 'ein'): 1,
#          ('vorgekommen', 'ein', 'kaninchen'): 1,
#          ('ein', 'kaninchen', 'mit'): 1,
#          ('kaninchen', 'mit', 'einer'): 1,
#          ('mit', 'einer', 'westentasche'): 1,
#          ('einer', 'westentasche', 'und'): 1,
#          ('westentasche', 'und', 'einer'): 1,
#          ('und', 'einer', 'uhr'): 1,
#          ('einer', 'uhr', 'darin'): 1,
#          ('uhr', 'darin', 'zu'): 1,
#          ('darin', 'zu', 'sehen'): 1,
#          ('zu', 'sehen', 'vor'): 1,
#          ('sehen', 'vor', 'neugierde'): 1,
#          ('vor', 'neugierde', 'brennend'): 1,
#          ('neugierde', 'brennend', 'rannte'): 1,
#          ('brennend', 'rannte', 'sie'): 1,
#          ('rannte', 'sie', 'ihm'): 1,
#          ('sie', 'ihm', 'nach'): 2,
#          ('ihm', 'nach', 'über'): 1,
#          ('nach', 'über', 'den'): 1,
#          ('über', 'den', 'grasplatz'): 1,
#          ('den', 'grasplatz', 'und'): 1,
#          ('grasplatz', 'und', 'kam'): 1,
#          ('und', 'kam', 'noch'): 1,
#          ('kam', 'noch', 'zur'): 1,
#          ('noch', 'zur', 'rechten'): 2,
#          ('zur', 'rechten', 'zeit'): 2,
#          ('rechten', 'zeit', 'um'): 1,
#          ('zeit', 'um', 'es'): 1,
#          ('um', 'es', 'in'): 1,
#          ('es', 'in', 'ein'): 1,
#          ('in', 'ein', 'großes'): 1,
#          ('ein', 'großes', 'loch'): 1,
#          ('großes', 'loch', 'unter'): 1,
#          ('loch', 'unter', 'der'): 1,
#          ('unter', 'der', 'hecke'): 1,
#          ('der', 'hecke', 'schlüpfen'): 1,
#          ('hecke', 'schlüpfen', 'zu'): 1,
#          ('schlüpfen', 'zu', 'sehen'): 1,
#          ('zu', 'sehen', 'den'): 1,
#          ('sehen', 'den', 'nächsten'): 1,
#          ('den', 'nächsten', 'augenblick'): 9,
#          ('nächsten', 'augenblick', 'war'): 3,
#          ('augenblick', 'war', 'sie'): 2,
#          ('war', 'sie', 'ihm'): 1,
#          ('ihm', 'nach', 'in'): 1,
#          ('nach', 'in', 'das'): 1,
#          ('in', 'das', 'loch'): 1,
#          ('das', 'loch', 'hi'): 1,
#          ('loch', 'hi', 'neingesprungen'): 1,
#          ('hi', 'neingesprungen', 'ohne'): 1,
#          ('neingesprungen', 'ohne', 'zu'): 1,
#          ('ohne', 'zu', 'bedenken'): 1,
#          ('zu', 'bedenken', 'wie'): 1,
#          ('bedenken', 'wie', 'in'): 1,
#          ('wie', 'in', 'aller'): 1,
#          ('in', 'aller', 'welt'): 2,
#          ('aller', 'welt', 'sie'): 1,
#          ('welt', 'sie', 'wieder'): 1,
#          ('sie', 'wieder', 'herauskommen'): 1,
#          ('wieder', 'herauskommen', 'könnte'): 1,
#          ('herauskommen', 'könnte', 'der'): 1,
#          ('könnte', 'der', 'eingang'): 1,
#          ('der', 'eingang', 'zum'): 1,
#          ('eingang', 'zum', 'kaninchenbau'): 1,
#          ('zum', 'kaninchenbau', 'lief'): 1,
#          ('kaninchenbau', 'lief', 'erst'): 1,
#          ('lief', 'erst', 'geradeaus'): 1,
#          ('erst', 'geradeaus', 'wie'): 1,
#          ('geradeaus', 'wie', 'ein'): 1,
#          ('wie', 'ein', 'tunnel'): 1,
#          ('ein', 'tunnel', 'und'): 1,
#          ('tunnel', 'und', 'ging'): 1,
#          ('und', 'ging', 'dann'): 1,
#          ('ging', 'dann', 'plötzlich'): 1,
#          ('dann', 'plötzlich', 'abwärts'): 1,
#          ('plötzlich', 'abwärts', 'ehe'): 1,
#          ('abwärts', 'ehe', 'alice'): 1,
#          ('ehe', 'alice', 'noch'): 1,
#          ('alice', 'noch', 'den'): 1,
#          ('noch', 'den', 'ge'): 1,
#          ('den', 'ge', 'danken'): 1,
#          ('ge', 'danken', 'fassen'): 1,
#          ('danken', 'fassen', 'konnte'): 1,
#          ('fassen', 'konnte', 'sich'): 1,
#          ('konnte', 'sich', 'schnell'): 1,
#          ('sich', 'schnell', 'festzuhalten'): 1,
#          ('schnell', 'festzuhalten', 'fühlte'): 1,
#          ('festzuhalten', 'fühlte', 'sie'): 1,
#          ('fühlte', 'sie', 'schon'): 1,
#          ('sie', 'schon', 'daß'): 1,
#          ('schon', 'daß', 'sie'): 1,
#          ('daß', 'sie', 'fiel'): 1,
#          ('sie', 'fiel', 'wie'): 1,
#          ('fiel', 'wie', 'es'): 1,
#          ('wie', 'es', 'schien'): 1,
#          ('es', 'schien', 'in'): 1,
#          ('schien', 'in', 'einen'): 1,
#          ('in', 'einen', 'tiefen'): 1,
#          ('einen', 'tiefen', 'tiefen'): 1,
#          ('tiefen', 'tiefen', 'brunnen'): 1,
#          ('tiefen', 'brunnen', 'entweder'): 1,
#          ('brunnen', 'entweder', 'mußte'): 1,
#          ('entweder', 'mußte', 'der'): 1,
#          ('mußte', 'der', 'brunnen'): 1,
#          ('der', 'brunnen', 'sehr'): 1,
#          ('brunnen', 'sehr', 'tief'): 1,
#          ('sehr', 'tief', 'sein'): 1,
#          ('tief', 'sein', 'oder'): 1,
#          ('sein', 'oder', 'sie'): 1,
#          ('oder', 'sie', 'fiel'): 1,
#          ('sie', 'fiel', 'sehr'): 1,
#          ('fiel', 'sehr', 'langsam'): 1,
#          ('sehr', 'langsam', 'denn'): 1,
#          ('langsam', 'denn', 'sie'): 1,
#          ('denn', 'sie', 'hatte'): 2,
#          ('sie', 'hatte', 'zeit'): 1,
#          ('hatte', 'zeit', 'genug'): 1,
#          ('zeit', 'genug', 'sich'): 1,
#          ('genug', 'sich', 'beim'): 1,
#          ('sich', 'beim', 'fallen'): 1,
#          ('beim', 'fallen', 'um'): 1,
#          ('fallen', 'um', 'zusehen'): 1,
#          ('um', 'zusehen', 'und'): 1,
#          ('zusehen', 'und', 'sich'): 1,
#          ('und', 'sich', 'zu'): 1,
#          ('sich', 'zu', 'wundern'): 1,
#          ('zu', 'wundern', 'was'): 1,
#          ('wundern', 'was', 'nun'): 1,
#          ('was', 'nun', 'wohl'): 1,
#          ('nun', 'wohl', 'geschehen'): 1,
#          ('wohl', 'geschehen', 'würde'): 1,
#          ('geschehen', 'würde', 'zuerst'): 1,
#          ('würde', 'zuerst', 'versuchte'): 1,
#          ('zuerst', 'versuchte', 'sie'): 1,
#          ('versuchte', 'sie', 'hinunter'): 1,
#          ('sie', 'hinunter', 'zu'): 1,
#          ('hinunter', 'zu', 'sehen'): 1,
#          ('zu', 'sehen', 'um'): 1,
#          ('sehen', 'um', 'zu'): 1,
#          ('um', 'zu', 'wissen'): 1,
#          ('zu', 'wissen', 'wohin'): 1,
#          ('wissen', 'wohin', 'sie'): 1,
#          ('wohin', 'sie', 'käme'): 1,
#          ('sie', 'käme', 'aber'): 1,
#          ('käme', 'aber', 'es'): 1,
#          ('aber', 'es', 'war'): 4,
#          ('es', 'war', 'zu'): 2,
#          ('war', 'zu', 'dunkel'): 1,
#          ('zu', 'dunkel', 'etwas'): 1,
#          ('dunkel', 'etwas', 'zu'): 1,
#          ('etwas', 'zu', 'erkennen'): 1,
#          ('zu', 'erkennen', 'da'): 1,
#          ('erkennen', 'da', 'besah'): 1,
#          ('da', 'besah', 'sie'): 1,
#          ('besah', 'sie', 'die'): 1,
#          ('sie', 'die', 'wände'): 1,
#          ('die', 'wände', 'des'): 1,
#          ('wände', 'des', 'brunnens'): 1,
#          ('des', 'brunnens', 'und'): 1,
#          ('brunnens', 'und', 'bemerkte'): 1,
#          ('und', 'bemerkte', 'daß'): 2,
#          ('bemerkte', 'daß', 'sie'): 2,
#          ('daß', 'sie', 'mit'): 2,
#          ('sie', 'mit', 'küchenschrän'): 1,
#          ('mit', 'küchenschrän', 'ken'): 1,
#          ('küchenschrän', 'ken', 'und'): 1,
#          ('ken', 'und', 'bücherbrettern'): 1,
#          ('und', 'bücherbrettern', 'bedeckt'): 1,
#          ('bücherbrettern', 'bedeckt', 'waren'): 1,
#          ('bedeckt', 'waren', 'hier'): 1,
#          ('waren', 'hier', 'und'): 1,
#          ('hier', 'und', 'da'): 2,
#          ('und', 'da', 'erblickte'): 1,
#          ('da', 'erblickte', 'sie'): 1,
#          ('erblickte', 'sie', 'landkarten'): 1,
#          ('sie', 'landkarten', 'und'): 1,
#          ('landkarten', 'und', 'bilder'): 1,
#          ('und', 'bilder', 'an'): 1,
#          ('bilder', 'an', 'haken'): 1,
#          ('an', 'haken', 'aufgehängt'): 1,
#          ('haken', 'aufgehängt', 'sie'): 1,
#          ('aufgehängt', 'sie', 'nahm'): 1,
#          ('sie', 'nahm', 'im'): 1,
#          ('nahm', 'im', 'vor'): 1,
#          ('im', 'vor', 'beifallen'): 1,
#          ('vor', 'beifallen', 'von'): 1,
#          ('beifallen', 'von', 'einem'): 1,
#          ('von', 'einem', 'der'): 1,
#          ('einem', 'der', 'bretter'): 1,
#          ('der', 'bretter', 'ein'): 1,
#          ('bretter', 'ein', 'töpfchen'): 1,
#          ('ein', 'töpfchen', 'mit'): 1,
#          ('töpfchen', 'mit', 'der'): 1,
#          ('mit', 'der', 'aufschrift'): 1,
#          ('der', 'aufschrift', 'eingemachte'): 1,
#          ('aufschrift', 'eingemachte', 'apfelsinen'): 1,
#          ('eingemachte', 'apfelsinen', 'aber'): 1,
#          ('apfelsinen', 'aber', 'zu'): 1,
#          ('aber', 'zu', 'ihrem'): 1,
#          ('zu', 'ihrem', 'großen'): 2,
#          ('ihrem', 'großen', 'verdruß'): 2,
#          ('großen', 'verdruß', 'war'): 1,
#          ('verdruß', 'war', 'es'): 1,
#          ('war', 'es', 'leer'): 1,
#          ('es', 'leer', 'sie'): 1,
#          ('leer', 'sie', 'wollte'): 1,
#          ('sie', 'wollte', 'es'): 1,
#          ('wollte', 'es', 'nicht'): 1,
#          ('es', 'nicht', 'fallen'): 1,
#          ('nicht', 'fallen', 'lassen'): 1,
#          ('fallen', 'lassen', 'aus'): 1,
#          ('lassen', 'aus', 'furcht'): 1,
#          ('aus', 'furcht', 'jemand'): 1,
#          ('furcht', 'jemand', 'unter'): 1,
#          ('jemand', 'unter', 'sich'): 1,
#          ('unter', 'sich', 'zu'): 1,
#          ('sich', 'zu', 'tödten'): 1,
#          ('zu', 'tödten', 'und'): 1,
#          ('tödten', 'und', 'es'): 1,
#          ('und', 'es', 'gelang'): 1,
#          ('es', 'gelang', 'ihr'): 1,
#          ('gelang', 'ihr', 'es'): 1,
#          ('ihr', 'es', 'in'): 1,
#          ('es', 'in', 'einen'): 1,
#          ('in', 'einen', 'andern'): 1,
#          ('einen', 'andern', 'schrank'): 1,
#          ('andern', 'schrank', 'an'): 1,
#          ('schrank', 'an', 'dem'): 1,
#          ('an', 'dem', 'sie'): 1,
#          ('dem', 'sie', 'vorbeikam'): 1,
#          ('sie', 'vorbeikam', 'zu'): 1,
#          ('vorbeikam', 'zu', 'schieben'): 1,
#          ('zu', 'schieben', 'nun'): 1,
#          ('schieben', 'nun', 'dachte'): 1,
#          ('nun', 'dachte', 'alice'): 1,
#          ('dachte', 'alice', 'bei'): 3,
#          ('alice', 'bei', 'sich'): 5,
#          ('bei', 'sich', 'nach'): 1,
#          ('sich', 'nach', 'einem'): 2,
#          ('nach', 'einem', 'solchen'): 1,
#          ('einem', 'solchen', 'fall'): 1,
#          ('solchen', 'fall', 'werde'): 1,
#          ('fall', 'werde', 'ich'): 2,
#          ('werde', 'ich', 'mir'): 1,
#          ('ich', 'mir', 'nichts'): 1,
#          ('mir', 'nichts', 'daraus'): 1,
#          ('nichts', 'daraus', 'machen'): 2,
#          ('daraus', 'machen', 'wenn'): 1,
#          ('machen', 'wenn', 'ich'): 2,
#          ('wenn', 'ich', 'die'): 2,
#          ('ich', 'die', 'treppe'): 1,
#          ('die', 'treppe', 'hin'): 1,
#          ('treppe', 'hin', 'unter'): 1,
#          ('hin', 'unter', 'stolpere'): 1,
#          ('unter', 'stolpere', 'wie'): 1,
#          ('stolpere', 'wie', 'muthig'): 1,
#          ('wie', 'muthig', 'sie'): 1,
#          ('muthig', 'sie', 'mich'): 1,
#          ('sie', 'mich', 'zu'): 1,
#          ('mich', 'zu', 'haus'): 1,
#          ('zu', 'haus', 'finden'): 1,
#          ('haus', 'finden', 'werden'): 1,
#          ('finden', 'werden', 'ich'): 1,
#          ('werden', 'ich', 'würde'): 1,
#          ('ich', 'würde', 'nicht'): 1,
#          ('würde', 'nicht', 'viel'): 1,
#          ('nicht', 'viel', 'redens'): 1,
#          ('viel', 'redens', 'machen'): 1,
#          ('redens', 'machen', 'wenn'): 1,
#          ('wenn', 'ich', 'selbst'): 1,
#          ('ich', 'selbst', 'von'): 1,
#          ('selbst', 'von', 'der'): 1,
#          ('von', 'der', 'dach'): 1,
#          ('der', 'dach', 'spitze'): 1,
#          ('dach', 'spitze', 'hinunter'): 1,
#          ('spitze', 'hinunter', 'fiele'): 1,
#          ('hinunter', 'fiele', 'was'): 1,
#          ('fiele', 'was', 'sehr'): 1,
#          ('was', 'sehr', 'wahrscheinlich'): 1,
#          ('sehr', 'wahrscheinlich', 'war'): 1,
#          ('wahrscheinlich', 'war', '9'): 1,
#          ('war', '9', 'hinunter'): 1,
#          ('9', 'hinunter', 'hinunter'): 1,
#          ('hinunter', 'hinunter', 'hinunter'): 2,
#          ('hinunter', 'hinunter', 'wollte'): 1,
#          ('hinunter', 'wollte', 'denn'): 1,
#          ('wollte', 'denn', 'der'): 1,
#          ('denn', 'der', 'fall'): 1,
#          ('der', 'fall', 'nie'): 1,
#          ('fall', 'nie', 'endi'): 1,
#          ('nie', 'endi', 'gen'): 1,
#          ('endi', 'gen', 'wie'): 1,
#          ('gen', 'wie', 'viele'): 1,
#          ('wie', 'viele', 'meilen'): 1,
#          ('viele', 'meilen', 'ich'): 1,
#          ('meilen', 'ich', 'wohl'): 1,
#          ('ich', 'wohl', 'jetzt'): 1,
#          ('wohl', 'jetzt', 'gefallen'): 1,
#          ('jetzt', 'gefallen', 'bin'): 1,
#          ('gefallen', 'bin', 'sagte'): 1,
#          ('bin', 'sagte', 'sie'): 2,
#          ('sagte', 'sie', 'laut'): 1,
#          ('sie', 'laut', 'ich'): 1,
#          ('laut', 'ich', 'muß'): 1,
#          ('ich', 'muß', 'ungefähr'): 1,
#          ('muß', 'ungefähr', 'am'): 1,
#          ('ungefähr', 'am', 'mittelpunkt'): 1,
#          ('am', 'mittelpunkt', 'der'): 1,
#          ('mittelpunkt', 'der', 'erde'): 1,
#          ('der', 'erde', 'sein'): 1,
#          ('erde', 'sein', 'laß'): 1,
#          ('sein', 'laß', 'sehen'): 1,
#          ('laß', 'sehen', 'das'): 1,
#          ('sehen', 'das', 'wären'): 1,
#          ('das', 'wären', 'achthundert'): 1,
#          ('wären', 'achthundert', 'und'): 1,
#          ('achthundert', 'und', 'funfzig'): 1,
#          ('und', 'funfzig', 'meilen'): 1,
#          ('funfzig', 'meilen', 'glaube'): 1,
#          ('meilen', 'glaube', 'ich'): 1,
#          ('glaube', 'ich', 'denn'): 1,
#          ('ich', 'denn', 'ihr'): 1,
#          ('denn', 'ihr', 'müßt'): 1,
#          ('ihr', 'müßt', 'wissen'): 1,
#          ('müßt', 'wissen', 'alice'): 1,
#          ('wissen', 'alice', 'hatte'): 1,
#          ('alice', 'hatte', 'dergleichen'): 1,
#          ('hatte', 'dergleichen', 'in'): 1,
#          ('dergleichen', 'in', 'der'): 1,
#          ('in', 'der', 'schule'): 2,
#          ('der', 'schule', 'gelernt'): 1,
#          ('schule', 'gelernt', 'und'): 1,
#          ('gelernt', 'und', 'obgleich'): 1,
#          ('und', 'obgleich', 'dies'): 1,
#          ('obgleich', 'dies', 'keine'): 1,
#          ('dies', 'keine', 'sehr'): 1,
#          ('keine', 'sehr', 'gute'): 1,
#          ('sehr', 'gute', 'gelegenheit'): 1,
#          ('gute', 'gelegenheit', 'war'): 1,
#          ('gelegenheit', 'war', 'ihre'): 1,
#          ('war', 'ihre', 'kenntnisse'): 1,
#          ('ihre', 'kenntnisse', 'zu'): 2,
#          ('kenntnisse', 'zu', 'zeigen'): 2,
#          ('zu', 'zeigen', 'da'): 1,
#          ('zeigen', 'da', 'niemand'): 1,
#          ('da', 'niemand', 'zum'): 1,
#          ('niemand', 'zum', 'zuhören'): 1,
#          ('zum', 'zuhören', 'da'): 1,
#          ('zuhören', 'da', 'war'): 1,
#          ('da', 'war', 'so'): 1,
#          ('war', 'so', 'übte'): 1,
#          ('so', 'übte', 'sie'): 1,
#          ('übte', 'sie', 'es'): 1,
#          ('sie', 'es', 'sich'): 1,
#          ('es', 'sich', 'doch'): 1,
#          ('sich', 'doch', 'dabei'): 1,
#          ('doch', 'dabei', 'ein'): 1,
#          ('dabei', 'ein', 'ja'): 1,
#          ('ein', 'ja', 'das'): 1,
#          ('ja', 'das', 'ist'): 2,
#          ('das', 'ist', 'ungefähr'): 1,
#          ('ist', 'ungefähr', 'die'): 1,
#          ('ungefähr', 'die', 'entfernung'): 1,
#          ('die', 'entfernung', 'aber'): 1,
#          ('entfernung', 'aber', 'zu'): 1,
#          ('aber', 'zu', 'wel'): 1,
#          ('zu', 'wel', 'chem'): 1,
#          ('wel', 'chem', 'länge'): 1,
#          ('chem', 'länge', 'und'): 1,
#          ('länge', 'und', 'breitegrade'): 1,
#          ('und', 'breitegrade', 'ich'): 1,
#          ('breitegrade', 'ich', 'wohl'): 1,
#          ('ich', 'wohl', 'gekommen'): 1,
#          ('wohl', 'gekommen', 'sein'): 1,
#          ('gekommen', 'sein', 'mag'): 1,
#          ('sein', 'mag', 'alice'): 1,
#          ('mag', 'alice', 'hatte'): 1,
#          ('alice', 'hatte', 'nicht'): 1,
#          ('hatte', 'nicht', 'den'): 1,
#          ('nicht', 'den', 'geringsten'): 2,
#          ('den', 'geringsten', 'begriff'): 2,
#          ('geringsten', 'begriff', 'was'): 1,
#          ('begriff', 'was', 'weder'): 1,
#          ('was', 'weder', 'längegrad'): 1,
#          ('weder', 'längegrad', 'noch'): 1,
#          ('längegrad', 'noch', 'breitegrad'): 1,
#          ('noch', 'breitegrad', 'war'): 1,
#          ('breitegrad', 'war', 'doch'): 1,
#          ('war', 'doch', 'klangen'): 1,
#          ('doch', 'klangen', 'ihr'): 1,
#          ('klangen', 'ihr', 'die'): 1,
#          ('ihr', 'die', 'worte'): 1,
#          ('die', 'worte', 'großartig'): 1,
#          ('worte', 'großartig', 'und'): 1,
#          ('großartig', 'und', 'nett'): 1,
#          ('und', 'nett', 'zu'): 1,
#          ('nett', 'zu', 'sagen'): 1,
#          ('zu', 'sagen', 'bald'): 1,
#          ('sagen', 'bald', 'fing'): 1,
#          ('bald', 'fing', 'sie'): 1,
#          ('fing', 'sie', 'wieder'): 1,
#          ('sie', 'wieder', 'an'): 3,
#          ('wieder', 'an', 'ob'): 1,
#          ('an', 'ob', 'ich'): 1,
#          ('ob', 'ich', 'wohl'): 2,
#          ('ich', 'wohl', 'ganz'): 1,
#          ('wohl', 'ganz', 'durch'): 1,
#          ('ganz', 'durch', 'die'): 1,
#          ('durch', 'die', 'erde'): 1,
#          ('die', 'erde', 'fallen'): 1,
#          ('erde', 'fallen', 'werde'): 1,
#          ('fallen', 'werde', 'wie'): 1,
#          ('werde', 'wie', 'komisch'): 1,
#          ('wie', 'komisch', 'das'): 1,
#          ('komisch', 'das', 'sein'): 1,
#          ('das', 'sein', 'wird'): 1,
#          ('sein', 'wird', 'bei'): 1,
#          ('wird', 'bei', 'den'): 1,
#          ('bei', 'den', 'leuten'): 1,
#          ('den', 'leuten', 'heraus'): 1,
#          ('leuten', 'heraus', 'zu'): 1,
#          ('heraus', 'zu', 'kommen'): 1,
#          ('zu', 'kommen', 'die'): 1,
#          ('kommen', 'die', 'auf'): 1,
#          ('die', 'auf', 'dem'): 1,
#          ('auf', 'dem', 'kopfe'): 1,
#          ('dem', 'kopfe', 'gehen'): 1,
#          ('kopfe', 'gehen', 'die'): 1,
#          ('gehen', 'die', 'antipathien'): 1,
#          ('die', 'antipathien', 'glaube'): 1,
#          ('antipathien', 'glaube', 'ich'): 1,
#          ('glaube', 'ich', 'diesmal'): 1,
#          ('ich', 'diesmal', 'war'): 1,
#          ('diesmal', 'war', 'es'): 1,
#          ('war', 'es', 'ihr'): 1,
#          ('es', 'ihr', 'ganz'): 2,
#          ('ihr', 'ganz', 'lieb'): 1,
#          ('ganz', 'lieb', 'daß'): 1,
#          ('lieb', 'daß', 'niemand'): 1,
#          ('daß', 'niemand', 'zuhörte'): 1,
#          ('niemand', 'zuhörte', 'denn'): 1,
#          ('zuhörte', 'denn', 'das'): 1,
#          ('denn', 'das', 'wort'): 1,
#          ('das', 'wort', 'klang'): 1,
#          ('wort', 'klang', 'ihr'): 1,
#          ('klang', 'ihr', 'gar'): 1,
#          ('ihr', 'gar', 'nicht'): 2,
#          ('gar', 'nicht', 'recht'): 1,
#          ('nicht', 'recht', 'aber'): 2,
#          ('recht', 'aber', 'natürlich'): 1,
#          ('aber', 'natürlich', 'werde'): 1,
#          ('natürlich', 'werde', 'ich'): 1,
#          ('werde', 'ich', 'sie'): 1,
#          ('ich', 'sie', 'fragen'): 1,
#          ...})

# %% [markdown]
# #### The most occuring sequence

# %%
# get the top frequent sequence
freq = collections.Counter(ngrams).most_common(20)
freq
# Out:
# [(('die', 'falsche', 'schildkröte'), 35),
#  (('sagte', 'der', 'könig'), 31),
#  (('sagte', 'die', 'falsche'), 18),
#  (('sagte', 'die', 'herzogin'), 17),
#  (('sagte', 'der', 'greif'), 16),
#  (('das', 'weiße', 'kaninchen'), 14),
#  (('sagte', 'die', 'raupe'), 14),
#  (('sagte', 'die', 'katze'), 13),
#  (('sagte', 'der', 'hutmacher'), 11),
#  (('zu', 'sich', 'selbst'), 10),
#  (('sagte', 'der', 'faselhase'), 10),
#  (('sagte', 'die', 'königin'), 10),
#  (('du', 'denn', 'nicht'), 10),
#  (('den', 'nächsten', 'augenblick'), 9),
#  (('die', 'arme', 'alice'), 8),
#  (('und', 'fing', 'an'), 8),
#  (('den', 'kopf', 'ab'), 8),
#  (('der', 'könig', 'und'), 8),
#  (('willst', 'du', 'denn'), 8),
#  (('denn', 'nicht', 'willst'), 8)]

# %% [markdown]
# #### Extracting Chunks
# convert the above list to a text file and save it in the hard disk for further use in language learning

# %% [markdown]
# The most frequent sequence is a list with a tuple of a tuple of words and time of occurance, i need to loop through all these to get the word sequence only

# %%
words_list = []
chunks = []
# first loop inside the list
for element in freq:
    for words in element:
        # ignore the frequence number and get only words tuple
        if type(words) !=  int:
            words_list.append(words)
            
# join words to get the chuncks
for word in words_list:
    sentence = " ".join(word)
    chunks.append(sentence)

chunks
# Out:
# ['die falsche schildkröte',
#  'sagte der könig',
#  'sagte die falsche',
#  'sagte die herzogin',
#  'sagte der greif',
#  'das weiße kaninchen',
#  'sagte die raupe',
#  'sagte die katze',
#  'sagte der hutmacher',
#  'zu sich selbst',
#  'sagte der faselhase',
#  'sagte die königin',
#  'du denn nicht',
#  'den nächsten augenblick',
#  'die arme alice',
#  'und fing an',
#  'den kopf ab',
#  'der könig und',
#  'willst du denn',
#  'denn nicht willst']

# %%
# save the chunks to a text file
with open("German_chunks.txt", "w") as output:
    output.write('\n'.join(chunks))

# %% [markdown]
# ### Results

# %% [markdown]
# Length of a chunk can be adjusted and saved to different files.

# %% [markdown]
# The text is not large enough to get feasible chunks. Most of chunks are one of the character saying something like 'said Alice'

# %% [markdown]
# I think, it's better if I used next time a complete tv series, so I get a regular conversation
